# %% [markdown]
# # EDA of Turtle Rescue Challenge

# %% [markdown]
# ### Table of Contents
# 1. <a href=#packages-and-data>Packages and Data</a>
# 2. <a href=#data-cleaning>Data Cleaning</a>
# 3. <a href=#2nd-table>Adding 2nd Table with Site Category Data</a>
# 4. <a href=#eda>EDA</a>
# 4. <a href=#baseline-model>Baseline Model</a>

# %% [markdown]
# ## Packages and Data

# %% [markdown]
# ### import packages

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, MetaData, Table

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, r2_score, mean_squared_error

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# Set random seed 
RSEED = 42
warnings.filterwarnings("ignore")

# %% [markdown]
# ### import csv data into dataframe

# %%
df = pd.read_csv('data/train.csv')
df
# Out:
#           Rescue_ID Date_TimeCaught     Researcher    CaptureSite
# 0      2000_RE_0060      2000-12-22  Researcher_25  CaptureSite_0  \
# 1      2001_RE_0187      2001-10-28   Researcher_6  CaptureSite_0
# 2      2001_RE_0197      2001-11-01   Researcher_6  CaptureSite_0
# 3      2002_RE_0031      2002-03-11  Researcher_32  CaptureSite_0
# 4      2002_RE_0118      2002-08-08  Researcher_25  CaptureSite_0
# ...             ...             ...            ...            ...
# 18057  2018_RE_1511      2018-12-18  Researcher_30  CaptureSite_9
# 18058  2018_RE_1514      2018-12-18  Researcher_30  CaptureSite_9
# 18059  2018_RE_1532      2018-12-24  Researcher_30  CaptureSite_9
# 18060  2018_RE_1533      2018-12-24  Researcher_30  CaptureSite_9
# 18061  2018_RE_1550      2018-12-28  Researcher_30  CaptureSite_9
#
#       ForagingGround CaptureMethod       Fisher
# 0              Ocean           Net  Fisher_1072  \
# 1              Ocean           Net   Fisher_520
# 2              Ocean           Net  Fisher_1669
# 3              Ocean           Net  Fisher_1798
# 4              Ocean       Beached  Fisher_1918
# ...              ...           ...          ...
# 18057          Ocean           Net   Fisher_569
# 18058          Ocean           Net   Fisher_125
# 18059          Ocean           Net  Fisher_1343
# 18060          Ocean           Net  Fisher_1551
# 18061          Ocean           Net  Fisher_1551
#
#                              LandingSite    Species           Tag_1  ...
# 0      LandingSite_CaptureSiteCategory_2  Species_6         CC00147  ...  \
# 1      LandingSite_CaptureSiteCategory_2  Species_6            W442  ...
# 2      LandingSite_CaptureSiteCategory_2  Species_5          KE0376  ...
# 3      LandingSite_CaptureSiteCategory_2  Species_6         CC00302  ...
# 4      LandingSite_CaptureSiteCategory_2  Species_5  NotTagged_0113  ...
# ...                                  ...        ...             ...  ...
# 18057  LandingSite_CaptureSiteCategory_1  Species_5         KES1828  ...
# 18058  LandingSite_CaptureSiteCategory_1  Species_6         KES0563  ...
# 18059  LandingSite_CaptureSiteCategory_1  Species_5         KES1833  ...
# 18060  LandingSite_CaptureSiteCategory_1  Species_5         KES1831  ...
# 18061  LandingSite_CaptureSiteCategory_1  Species_6         KES1432  ...
#
#       Lost_Tags T_Number CCL_cm  CCW_cm  Weight_Kg      Sex
# 0           NaN      NaN  64.70   62.60        NaN  Unknown  \
# 1           NaN      NaN  35.85   31.35        NaN  Unknown
# 2           NaN      NaN  51.80   49.20        NaN  Unknown
# 3           NaN      NaN  60.50   59.00        NaN  Unknown
# 4           NaN      NaN  34.70   33.00        NaN  Unknown
# ...         ...      ...    ...     ...        ...      ...
# 18057       NaN      NaN  57.13   50.57      21.09  Unknown
# 18058   KES0416      NaN  42.07   38.37       9.02  Unknown
# 18059       NaN      NaN  57.20   52.30        NaN  Unknown
# 18060       NaN      NaN  51.90   48.50        NaN  Unknown
# 18061       NaN      NaN  34.60   31.20       4.29  Unknown
#
#                                    TurtleCharacteristics    Status
# 0                                 algae at rear of shell  Released  \
# 1      multiple b's on front flippers&  a lot of alga...  Released
# 2                                                  clean  Released
# 3      1 b 3 CS+ calcerous algae at rear end of shell...  Released
# 4      very lively+ right eye is hanging out + swolle...  Released
# ...                                                  ...       ...
# 18057                 White calcareous algae on carapace  Released
# 18058  Calcareous + green algae on carapace\nBarnacle...  Released
# 18059                                       Clean turtle  Released
# 18060  Green algae on carapace\ntip of left supra mis...  Released
# 18061  Thick pink patches of calcareous algae on cara...  Released
#
#           ReleaseSite Date_TimeRelease
# 0      ReleaseSite_50         22/12/00
# 1      ReleaseSite_62         28/10/01
# 2      ReleaseSite_50         01/11/01
# 3      ReleaseSite_50         11/03/02
# 4      ReleaseSite_62         08/08/02
# ...               ...              ...
# 18057  ReleaseSite_68         18/12/18
# 18058  ReleaseSite_68         18/12/18
# 18059  ReleaseSite_68         24/12/18
# 18060  ReleaseSite_68         24/12/18
# 18061  ReleaseSite_37         28/12/18
#
# [18062 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18062 entries, 0 to 18061
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rescue_ID              18062 non-null  object
#  1   Date_TimeCaught        18062 non-null  object
#  2   Researcher             18062 non-null  object
#  3   CaptureSite            18062 non-null  object
#  4   ForagingGround         18062 non-null  object
#  5   CaptureMethod          18062 non-null  object
#  6   Fisher                 18062 non-null  object
#  7   LandingSite            18062 non-null  object
#  8   Species                18062 non-null  object
#  9   Tag_1                  17937 non-null  object
#  10  Tag_2                  4911 non-null   object
#  11  Lost_Tags              925 non-null    object
#  12  T_Number               38 non-null     object
#  13  CCL_cm                 18038 non-null  float64
#  14  CCW_cm                 18035 non-null  float64
#  15  Weight_Kg              12653 non-null  float64
#  16  Sex                    13732 non-null  object
#  17  TurtleCharacteristics  18010 non-null  object
#  18  Status                 14429 non-null  object
#  19  ReleaseSite            17987 non-null  object
#  20  Date_TimeRelease       11954 non-null  object
# dtypes: float64(3), object(18)
# memory usage: 2.9+ MB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### dropping columns unrelated to number and location of turtle captures
# ##### Tag 1, Tag 2, Lost Tags, Tag Number, Sex, Characteristics, Status, Release Site, Date/Time Release
# (for now keeping: Researcher, Fisher, Foraging Ground, Capture Method, Landing Site, Species, Length, Weight, even if later dropped)

# %%
columns_drop = ['Tag_1', 'Tag_2', 'Lost_Tags', 'T_Number', 'Sex', 'TurtleCharacteristics', 'ReleaseSite', 'Date_TimeRelease']
df.drop(columns=columns_drop, inplace=True)
df
# Out:
#           Rescue_ID Date_TimeCaught     Researcher    CaptureSite
# 0      2000_RE_0060      2000-12-22  Researcher_25  CaptureSite_0  \
# 1      2001_RE_0187      2001-10-28   Researcher_6  CaptureSite_0
# 2      2001_RE_0197      2001-11-01   Researcher_6  CaptureSite_0
# 3      2002_RE_0031      2002-03-11  Researcher_32  CaptureSite_0
# 4      2002_RE_0118      2002-08-08  Researcher_25  CaptureSite_0
# ...             ...             ...            ...            ...
# 18057  2018_RE_1511      2018-12-18  Researcher_30  CaptureSite_9
# 18058  2018_RE_1514      2018-12-18  Researcher_30  CaptureSite_9
# 18059  2018_RE_1532      2018-12-24  Researcher_30  CaptureSite_9
# 18060  2018_RE_1533      2018-12-24  Researcher_30  CaptureSite_9
# 18061  2018_RE_1550      2018-12-28  Researcher_30  CaptureSite_9
#
#       ForagingGround CaptureMethod       Fisher
# 0              Ocean           Net  Fisher_1072  \
# 1              Ocean           Net   Fisher_520
# 2              Ocean           Net  Fisher_1669
# 3              Ocean           Net  Fisher_1798
# 4              Ocean       Beached  Fisher_1918
# ...              ...           ...          ...
# 18057          Ocean           Net   Fisher_569
# 18058          Ocean           Net   Fisher_125
# 18059          Ocean           Net  Fisher_1343
# 18060          Ocean           Net  Fisher_1551
# 18061          Ocean           Net  Fisher_1551
#
#                              LandingSite    Species  CCL_cm  CCW_cm
# 0      LandingSite_CaptureSiteCategory_2  Species_6   64.70   62.60  \
# 1      LandingSite_CaptureSiteCategory_2  Species_6   35.85   31.35
# 2      LandingSite_CaptureSiteCategory_2  Species_5   51.80   49.20
# 3      LandingSite_CaptureSiteCategory_2  Species_6   60.50   59.00
# 4      LandingSite_CaptureSiteCategory_2  Species_5   34.70   33.00
# ...                                  ...        ...     ...     ...
# 18057  LandingSite_CaptureSiteCategory_1  Species_5   57.13   50.57
# 18058  LandingSite_CaptureSiteCategory_1  Species_6   42.07   38.37
# 18059  LandingSite_CaptureSiteCategory_1  Species_5   57.20   52.30
# 18060  LandingSite_CaptureSiteCategory_1  Species_5   51.90   48.50
# 18061  LandingSite_CaptureSiteCategory_1  Species_6   34.60   31.20
#
#        Weight_Kg    Status
# 0            NaN  Released
# 1            NaN  Released
# 2            NaN  Released
# 3            NaN  Released
# 4            NaN  Released
# ...          ...       ...
# 18057      21.09  Released
# 18058       9.02  Released
# 18059        NaN  Released
# 18060        NaN  Released
# 18061       4.29  Released
#
# [18062 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18062 entries, 0 to 18061
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rescue_ID        18062 non-null  object
#  1   Date_TimeCaught  18062 non-null  object
#  2   Researcher       18062 non-null  object
#  3   CaptureSite      18062 non-null  object
#  4   ForagingGround   18062 non-null  object
#  5   CaptureMethod    18062 non-null  object
#  6   Fisher           18062 non-null  object
#  7   LandingSite      18062 non-null  object
#  8   Species          18062 non-null  object
#  9   CCL_cm           18038 non-null  float64
#  10  CCW_cm           18035 non-null  float64
#  11  Weight_Kg        12653 non-null  float64
#  12  Status           14429 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#              CCL_cm        CCW_cm     Weight_Kg
# count  18038.000000  18035.000000  12653.000000
# mean      43.090390     40.253904      9.850731
# std       11.004251      9.933058      9.737378
# min        2.000000      2.000000      0.020000
# 25%       36.330000     34.000000      5.000000
# 50%       41.300000     39.300000      7.500000
# 75%       47.000000     44.100000     10.800000
# max      122.750000    106.000000    140.000000

# %%
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm               24
# CCW_cm               27
# Weight_Kg          5409
# Status             3633
# dtype: int64

# %% [markdown]
# #### (CCL_cm, CCW_cm and Weight_Kg have NaNs that need to be filled in!)

# %%
df.nunique()
# Out:
# Rescue_ID          18062
# Date_TimeCaught     5237
# Researcher            35
# CaptureSite           29
# ForagingGround         3
# CaptureMethod         15
# Fisher              2085
# LandingSite            5
# Species                8
# CCL_cm              1338
# CCW_cm              1262
# Weight_Kg           1937
# Status               439
# dtype: int64

# %%
df['Status'].unique()
# Out:
# array(['Released', ' 2smb 3LLS& 1sm b R supra',
#        ' b scar 4RMS& 2LLS& 4LLS',
#        ' sm patches of calcerous algae on shell and supras',
#        ' b join 3/4 LLS', nan, 'Admitted', ' chips on RM',
#        ' tip of RS CS missing',
#        " quite large piece missing from 1 + 2 scale area on LFF - possibly old tagging+ but unlikley that tagged there and piece is large+ maybe old wound.  a lot of small b's on flesh",
#        ' green algae on scutes',
#        ' no other major physical characteristics',
#        ' light green algae on scutes', ' no other major characteristics',
#        ' 6 LLS& small notch in the joints between both 10th and 11th MS',
#        ' B scar on 1st CS', ' notch on LRF',
#        ' few small barnacles on carapace', ' barnacles on ???',
#        ' tiny barnacles on plastron', ' green algae on rear carapace',
#        ' small barnacles on neck', ' small barnacles on flippers',
#        ' RSCS tip missing', ' green algae on carapace',
#        ' 7+ 9 + 10 LM scutes have some chips',
#        " many b's at joint between 1 LLS and marginals + 1 RLS and marginals. Many barnacles across carpace and flippers",
#        ' end of LFF + inside edge RFF-little bleeding from net+ both rear flippers have a piece missing',
#        ' much whitish -pinkish calcerous algae growth over rear-end of shell+ RFF has a large notch+ LFF has a small notch+ many small bs on all 4 flippers',
#        ' did not tag it. 6 central scutes not symetrical. Chipping on carapace.',
#        ' between 8/10& 10 & 11 LMS has a chip. ', ' RRF piece missing',
#        ' notch btw 9/10RMS & on 11RMS & 9LMS', ' sm b on 2LLS& notch LRF',
#        ' calcerous algae CS + supras', 'Not_Recorded',
#        ' V-shaped notch in RRF', ' notch on the second RCS',
#        ' pink algae on plastron', ' light green algae on rear carapace',
#        ' tip of LRF missing', ' brown algae around neck and tail',
#        ' pieces of both FF are missing',
#        ' white patches of calcareous algae on scutes',
#        ' pinkish calcareous algae on plastron',
#        ' barnacles on carapace and plastron',
#        ' small barnacles on flippers and around neck',
#        ' brown algae and small barnacles around the neck',
#        ' pinkish calcareous algae on carapace',
#        ' clean carapace and plastron', ' small hole on tenth RMS and LMS',
#        ' loose projection at edge of RRF ',
#        'LF flip sm injury & slight bleeding. Barnacles on RLS and 2LM.',
#        '  3 CS has a fairly large indentation+ 10 LMS has a notch in it+ 6 RMS has a small chip+ 7 RMS has a very small chip',
#        " left supra has a chip out of it& small piece out of left rear flipper missing.  Note:  tag was full of small b's -all killed.",
#        ' sea lice in eyes', ' sm bs 4LLS',
#        ' light green alage on shell& old scar from fishing line entanglement on LFF',
#        ' B on 2nd RLS& small bs on neck & RFs& scratch on 1st CS& 1b on 10th LMS+ L supracaudal +11th RM',
#        ' RMS 10-11 notches',
#        ' notch in the middle of the inner edge of LFF',
#        ' chip in 9th RMS', ' shell is beginning to flake',
#        ' the edge of 7th& 8th& 9th and both 11th MS are jagged',
#        ' eight LMS is deformed', ' pink & calcerous algae at rear',
#        ' LRflip lareg piece missing', ' notch 9LM', ' ',
#        ' btw 9/10 & 11/12 LM piece missing',
#        "  3 b's 5 CS+ 1 small b on 3 CS + 4 CS+ some red algae around b's",
#        ' ssuperfical damage 5 CS and 11 LM joint& has 6 CS-5th is very small.',
#        ' very heavy encrusting calcerous algae all over the shell and green/red algae on marginals& 9 RM and 6 LM has a c',
#        ' scratshed 2+3LLS', ' v-notch on LRF', ' 1b 11RM + 5CS.',
#        ' b scar 3LLS& 6LMS', ' sm notch on LFF& sereted edges of MS',
#        ' notch RRF', ' pinkish calcerous algae on rear shell ',
#        ' sm bs on 2&4RLS and flips',
#        ' brown algae on neck and under flips', ' flakings 4+5CS',
#        ' 7RMS is sunken with white calcerous algae',
#        ' pink calcerous algae 4RLS and supra', ' several notches in RMS',
#        ' small Bs on rear shell', ' chip in 5th RMS',
#        ' no flesh around neck]. U-notch RRF. Releasing dark brown fluid from cloaca',
#        ' green and white calcareous algae on the carapace',
#        ' turtle generally healthy and active',
#        ' healthy and active turtle', ' no other major physical features',
#        ' tiny barnacles underneath LRF', ' green algae on plastron',
#        ' five post-oculars on left side', ' notches on eleventh RMS',
#        ' light green algae on carapace', ' sm chip 10/11 RMS',
#        "   several b's on shell (all killed)& has 6 CS(5 CS is very small)& very small b's on flippers and neck area& tip of right front flipper is slightly jagged.",
#        ' flaking on 2nd CS and 4th CS', ' right supracaudal broken',
#        ' flaking on 1& 2 & 3 CS and 3 LLS',
#        ' small bs on the shoulders &  the LFF+LRF and on the joints of the scutes&supracaudal is slightly broken.',
#        ' light green algae on shell',
#        ' Bs on 1&2&5CS & 3&4LLS & 10&11RMS & R supra', ' flaking',
#        ' light pink calcerous algae on rear shell',
#        ' small v-shaped notch on LRF', ' shell is slightly flaking',
#        ' small barnacles', ' 8 CS (in zig-zag pattern)',
#        ' generally clean turtle',
#        " piece missing on right flipper& open wound (fresh) on the neck-might be from the net& many small b's on underside",
#        ' right supra. has chip.',
#        ' Large barnacle on the 1st RLS& Light covering of green algae on the shell',
#        ' bs 2&4&5 CS & 2&3LLS',
#        ' light green algae on shell& 7bs on plastron& cuts on rear flips',
#        ' sometiny barnacles on flippers', ' b 9LM',
#        ' calcerous algae 11LM& nuchal& 1CS.',
#        ' healing 1Green Turtle wound on neck & half Green Turtle wound on neck in fron tof LMS',
#        ' light pink calcerous', ' flaking on 2 RLS',
#        '.BS on flippers. Green algae on plastron.',
#        ' upper and lower beak are ont properly aligned',
#        ' green algae towards rear carapace',
#        ' patches of pinkish calcareous algae on the carapace',
#        'shoulder. Pinkish algae on plastron.',
#        ' barnacle on plastron (removed)',
#        ' tiny barnacles on all flippers and around neck', ' clean turtle',
#        ' some green algae on rear carapace',
#        ' thin green algae on rear carapace', ' 5 LLS',
#        ' white patches of calcareous algae on carapace',
#        ' eigth LMS deformed', ' turtle looks weak',
#        ' small barnacles on plastron (removed)', ' tip of RRF missing',
#        ' notch RF flip', ' sm Bs down central scutes +left marginals',
#        ' left rear flip - cut on trailing edge& +1/2 norm size. Both original tags lost (CC00198 & W444)',
#        " marginals damaged serrations eroded way - caused by b's underneath",
#        "   b-1RLS& 5 b's 2 RLS& 1 b 3 RLS& 8 b's 6 CS& 1 b 11 marg.& 3 b's 3 LLS& 1 b 1 4 LLS& 6 CS's- b.  Front flippers at edge have a little net damage",
#        ' RR flipper has old bite out of it', ' no LR flip',
#        ' 1 small b-3LM+ 1 small b-4LLS+ small B cluster - 4RLS+ 2 RLS has superficial damage to shell (1inch squar',
#        ' 2Bs on 5CS& 11LMS&10RMS (killed)& Bs on plastron',
#        ' 3rd CS is beginning to flake',
#        ' the 2nd 3rd of both FFS from tips are jagged',
#        ' a v-shaped notch in mid-inner edge LFF',
#        ' a small projection on the middle of RRF', ' clean plastron',
#        ' barnacles around the neck', ' notch between supras', ' 12 LMS',
#        ' 5 RLS', ' small barnacles around neck and rear flippers',
#        ' notches on RMS', ' thin green algae on carapace',
#        ' barnacles on plastron (removed)',
#        ' barnacles on carapace (removed)',
#        ' white calcareous algae on edge of scutes', ' deformed third CS',
#        ' some patches of calcareous algae on the carapace',
#        ' small Bs on the shoulders', ' both supra are raised',
#        ' covered lightly on plastron with red & green algae blotches& slight bleeding underside of jaw +underside of left flipper betwe',
#        ' a little red algae in neck and shoulder areas',
#        " very small b's on flippers",
#        " many small b's at rear end of shell and marginals& also b's ingrowing in shell on 3 RLS and at joint of 1/2 LLS & RLS (causing uplift  of scute on 3 RLS)& all b's killed& very scarred shell& light algae covering& litt",
#        ' some Bs on scutes and flippers',
#        ' taken to rehabilitation center',
#        ' thick green algae on rear shell and rear flippers',
#        ' light white calcareous algae on carapace',
#        ' some notches on the rear marginal scutes',
#        ' few barnacles on carapace', ' carapace flaking on fourth LS',
#        ' b scar 2LLS& fresh net injuries on shoulder - a little bleeding',
#        ' sm b on 5CS', ' several small barnacles on the plastron',
#        ' clean plastron and carapace', ' both tips of supras missing',
#        ' notch on ninth RMS', ' tag rip on LRF',
#        ' Bs interfered with measuring ',
#        ' couple of small notches on inside of RFF on 2nd scale. Light algae covering& hook wound (small hole) under LFF.    ',
#        ' hooked in mouth with squid bait& big B surrounded by smaller on 3CS and 11RMS& notch join 9/10RMS& light green algae on rear of shell',
#        ' flkaing 11RMS and plastron',
#        'll additional scute between 10th LMS and 5th CS. A big notch in 10th RMS. Shalow notch in 10th LMS. A tag hole in LRF.',
#        'aking shell.', ' scratch marks on 2nd CS and 1st RLS',
#        ' few barnacles on left front flipper',
#        ' few small barnacles on the plastron',
#        ' flake on the left 2nd left lateral scute',
#        ' few small barnacles on the right carapace and plastron',
#        ' nuchal scute and first CS not well defined',
#        ' tip of LSCS broken', ' notch between tenth and eleventh LMS',
#        ' both supra tips missing', ' flking on nuchal scute',
#        ' notch on eleventh RMS', ' tip of supras damaged', ' b scar 2LLS',
#        ' 2 Bs on 4 RLS', ' beautiful in colour', ' notch on fifth CS',
#        ' underside covered in Bs& especialy heavy around margi',
#        ' little bleeding from rear marg',
#        ' pinky skin colour on underside of rear flips +tail areas',
#        " 2nd LLS is flaking& all scutes are flaking& 1LLS large b& 3LLS has 3 large b's +clusters& 2RLS has 4 large b's +clusters& supracaudals damaged -slight bleeding& tag rip in LRF",
#        ' underside of left& right & rear marginals have algae  ',
#        ' slight chipping of all scutes& which were slightly elevated',
#        ' white calcerous algae at end of marginals', ' 2smBs 4RLS',
#        ' light algae on shell& heavy on 2CS',
#        ' 1+ 2 3 RLS and 2 + 3 LLS has chips+ between 7 + 8 RMS has a chip ',
#        " hook went in under LFF+ small wound end of RFF+ small b's on 3CS+ notch out of left + right suprac.",
#        '  mark to shell between 2+ 3RLS',
#        " chip btw R supra/11RM+ small b left supra+ very small b's on the sides of head",
#        '  very beautiful shell+ 3 RMS + 8 LMS have 1 small b each+ 7 + 8 RMS have notches+ 8 + 10 LMS have notches+',
#        " notch off R supra.+ small b's on left front flipper on top+ small hole LFF (old b scar)+ small b on RFF+ shell perfect. Old tag mark on the the left flipper",
#        ' square LFF-end with the thickened area and old wound',
#        ' 3 RLS has large b and 11 RMS has 1 b+ a bit of chipping off on right supra.+ wound under RFF because of the hook+ tips of flippers (rear) a bit damaged.',
#        ' 2 LLS has some flaking& 1 small barnacle (b) on nuchal& 11 RMS has a chip put of it& left rear flipper has a notch',
#        ' has 5 RLS and has 12 MS& a little rawness from net on LFF& and a notch between supra.',
#        ' 1& 3& 4 RLS has marks& 2 RLS has flaking& 3 CS has small b& right flipper with indent& b over right eye.',
#        ' the R supra edge is broken&light grenish algae smear on  2&3LLS.& a flaking on 6RMS. tag replaced almost falling off',
#        ' gr', ' 4CS& 3RLS& 4RLS&5CS has 1 b',
#        " small b's on 4RMS& 11RMS & on neck & RFs",
#        ' A b on the 2nd RMS& 2RLS& 5th CS and bs on the RFs. 2notches on the 11RMS',
#        ' gren algae on shell', ' RRF missing: b scar 8&9 RMS',
#        ' sm bs on LFF & 11 L&RMS', ' small B on RLS',
#        ' sunken laterals& small chips on LFF',
#        ' B scar on joint of 1 and 2 RLS', ' 1B 5CS',
#        ' B scar on the 1st CS& b on the RLS& left supracaudal is broken & a small notch on the 11th LMS& soft algae on the carapace ',
#        ' RRF has alareg piece missing at top of flip',
#        ' v. sm non FOP growth top right side of RRF', ' 2b 3RLS',
#        ' notches on both MSs 8>11',
#        ' b scar join 1CS/1LLS& notch join 8/9LMS',
#        ' Light green algea on shell&B scar on 3rdLLS', ' Clean shell&',
#        ' hook wound on RFF shoulder', ' b interference on CCW',
#        ' flaking 6th LMS + 11th RMS',
#        ' flaking on both 1st LS& 1st to 4th LMS + 1st to 3rd RMS',
#        ' 4B RFF',
#        ' Flaking on 3rd-4th LLS& 3rd RLS& 3rd-5th CS& barnacle on 8th LMS + notch& small barnacles all flipps& notch on LRF& deformed RFF',
#        ' minor flaking patches on scutes', ' tag rip in LRF',
#        ' hook injury in the right shoulder',
#        ' bleeding bruise at top of RFF', ' small Bs on scutes + head',
#        ' flaking. Inactive.', ' small notches on tenth LMS and RSCS',
#        ' tiny barnacles on neck and rear carapace',
#        ' few tiny barnacles on carapace', ' small barnacles on carapace',
#        'flaking shell', ' few smal barnacles around neck and shoulders',
#        ' missing LFF', ' healthy turtle', ' notch on tenth RMS and LRF',
#        " 3 RLS-3 large b's& 3 LLS and 4 RLS-1 very large b& 4 LLS-6 b cluster& flaking 4 RLS& scute damage 3 RLS (some scutes not there down to bone - 3 inch patch)& burrowing b in 5 LLS& 4 LLS& 3 LLS& quite a bit of flaking all over shell especially supra.&",
#        ' many sm bs on flipps', ' turtle appears weak',
#        ' few tiny barnacles on shoulders and flippers',
#        ' slightly broken ninth LMS', ' 5 post-orbitals on right side',
#        ' fifth CS split into 2/3', ' 1 b 5 CS & 1 small',
#        " old tag cut out from turtle - piece of flesh missing in rear flipper.  Chip on 10 & 11 L marginal & 10 R marginal& 2 RLS & 3 LLS old b wound& 2 RLS has impregnated b&  9 RLS has 1 small b& 4 large b's on upper b",
#        ' hump 1 CS+ small superficial shell damage 5 CS ',
#        " 2 b's on plastron& green algae growth over shell& old b scar 3 LLS& 11 LMS has 2 small chips& small b on top of head. Old tag scar LRF",
#        " 5 LLS& several small b's towards rear end of shell& small b's on flippers and neck& 8 RMS has a chip& left front flipper has a notch at the tip.",
#        ' flakings on 9 &10RMS& and on 9> 11LMS ', ' sm bs on 2 RMS',
#        ' sm b join of 8/9 LMS& sm bs on supras and 11RMS',
#        ' sm bs on shell', ' small Bs on shoulders', ' 1 B on 11th LMS',
#        ' chips on supras & b on R supra', ' small net damage on flippers',
#        ' B on 11LM& 11RM& 3 bs on R. supracaudal.', ' 1 b on head& 7RMS',
#        ' Clean', ' b 4RLS& 10RMS',
#        ' b 5CS& B cluster on plastron - all bs killed',
#        ' large bs on 2LLS& 4LLS& 4&5 CS', ' net redness tip of FFs',
#        ' sm scrape on 4RLS', ' sm bs 2RLS& both 11MS & 2LLS',
#        ' sm bs on 1RLS and 3LLS', ' sm bs RFs', ' 1 lge b 4LLS',
#        ' b onm 4RLS& b scar3RLS& light green alage on shell& sm hook wound RFF near shoulder',
#        ' 1B 1&3&5CS& 2small Bs 11RMS& flaking 5CS+1stLLS& chip 9LM+R.supra',
#        ' 2Bson 2ndRLS& 1b on 3rdRLS& 8LM-large chip',
#        ' 1B on 5thCS& R supra&L supra',
#        ' deep large cut(2Green Turtle)on soft flesh next to LFF (from hook)& 2bs LFFat middle& a chip on 8thRMS',
#        ' few small removed Bs on scutes',
#        ' small notch in 11th LMS& small Bs on neck', ' small Bs on neck',
#        ' tag lump in RRF', ' notch in the joint between 10th +11th LMS',
#        ' tag rips in both RF& a projection at the middle of LRF',
#        ' 13 scars on shell', ' flaking shell and plastron',
#        ' few barnacles removed. Two shallow wounds on right pectoral scale of the plastron. Pinkish composition on the majority of the scales of the pastron.',
#        ' and also between 7th and 8th LmS. Flaking on the carapace. Thin green algae on the carapace.',
#        ' tag rip on the left rear flipper',
#        ' small scute between 4th and 5th central scutes',
#        ' at rear minor flaking third CS',
#        ' minor notches on rear flipper', ' bottom tips on supras missing',
#        ' minor flaking on carapace', ' flaking on carapace and plastron',
#        ' otherwise generally clean turtle', ' minor flakings on plastron',
#        'damage LR flipper', ' slight damage to LF flip',
#        ' turtle is fat & healt', ' sm bs on shouldrs and flipps',
#        ' thicjk green algae over shell& emaciated and weak…..DIED 22/9',
#        ' calcerous algae on scutes', ' badly dehydrated',
#        ' neck& eyes and LRF (big tumour)& thick green algae on the carapace& sent to rehab( euthenised)',
#        ' irregular scutes 6CS& 5LLS& 4RLS',
#        "  B's on head& left f flipper edge& right f flipper edge",
#        ' 11L marg missing & 10th partially  ', ' 2Bs 3RLS',
#        '  has  5 LLSs',
#        " b cluster on 3 CS+  underside of RF flipper has deep gash where hook caught the turtle+ 3 small b's on R prefontal of head. Both origina",
#        ' right supra. has a chip.',
#        " b scar 1 LLS& 3 b's 2 RLS and 3 RLS",
#        ' L supra tip is off&small jagged on both FF',
#        ' flaking off of the 4LLS&5C', ' chip on 11th LMS',
#        ' small Bs on supracaudal', ' indent 7>11LMS',
#        ' sm hole near tip of RFF', ' flakings 2LLS& 3CS',
#        ' healing speargun wounds both sides of neck',
#        ' small Bs on shoulder and 3rd CS',
#        ' tiny barnacles on rear carapace and around neck',
#        ' first LMS has a splighting joint', ' 2RLS - 1B',
#        ' the edges of the marginal scutes are serrated.',
#        ' 1Green Turtle superficila scute damage 4RLS',
#        'many bs on plastron',
#        ' wound could have been caused by predators.',
#        ' green algae on the plastron',
#        ' green algae on the rear carapace',
#        ' small barnacles on plastron',
#        ' white calacareous algae on carapace', ' 3 sm ingrowing bs 3RLS',
#        ' three holes on the 1LMS& 1 hole on the 8RMS&10&11 RMS are broken ',
#        ' notch 11LMS', ' slight algae on supracaudal', ' notch on 7 RMS',
#        ' flakings on CS', 'b scar 4RMS& pink calcerous algae 3&5CS',
#        ' notch btw 7/8 & 9/10 RMS',
#        ' massive neck wounds to top of neck - looks like spear wound into right of neck& with machete wound to top of neck (open) but started healing& bone in tact',
#        ' old b scar on 1CS& left eye bulbous + bloodshot',
#        ' net wounds FFs& sm notches joins 9/10/11LMS',
#        ' speargun wounds on left side of neck with swelling& sunken plastron& 2 notches in RRF',
#        ' b 1CS and join 2/3RLS& flakings 2RLS',
#        ' bleeding at tag site as fisherman had tried to remove it',
#        ' 1CS is divided in 2',
#        ' flaking on joints of scutes& scar on 3rd LLS& few small barnacles on flippers',
#        ' some chipping in MS on both sides', ' 2nd& 3rd left LS',
#        " small b's on 3rd & 4th LLS & 3rd & 4th CS +2 RLs   ",
#        " 2 LLS has a chip+ 2 small b's on nuchal + small b on supra.+ few bs on shell and flippers+ some small b's to the right side of head to the back+ some flipper damage on LFF - net+ chip between ",
#        ' 1 small b -4 LLS& 9 LMS& both supra. and 4 CS',
#        ' a cluster of b on 2LLS and one on each 3 &4LLS& b on the 9& 10 LMS& fresh wound on the front flippers (net damage)',
#        ' light flaking on shell& sm b on L supra', ' notches on both RFs',
#        ' light green alage on shell& 9LM has chip&  sm bs RFs ',
#        ' Small hump on 1st CS& flaking on 2nd + 3rd LLS + 2nd + 4th RLS& notches on the 9th + 10th LMS + left supra& notches on 8th + 9th RMS& small hook wound on LFF',
#        ' greenish algae on carapace', ' notch in supra',
#        'aking plastron. A tag rip in LRF. ',
#        ' tag rips in both rear flippers',
#        ' notch between ninth and tenth LMS',
#        ' 3 post-orbitals on the left side', ' flake on the second LLS',
#        ' flaking on carapace', ' scratches',
#        " bleeding wound on RFF from hook between flipper and body& 2 small b's on 2 LM& 1 small b 10 RMS& right supra has small b's& 5 CS has 2 small b clusters& very small b cluster 9 LMS& chip 8 LMS and right supra.",
#        ' 6CS& 5 R&L LS (5th CS and $R&L LS are small)',
#        ' flaking of 4RLS& 9&10RMS', ' long line has 60 hooks& 1 every 2m',
#        ' hooked in right shoulder& bait squid',
#        ' shell beginning to flake', ' LF flip notched',
#        ' many Bs on all 4 flips+ edge of LRF small piece missing+ small gash on 2LMS   lots of pinkish irration undernesth flippers and neck. Right shoulder is an old wound',
#        ' greenish algae on right side',
#        " lot of s b's on flippers+ flesh+ shells + head-especially at scutes joint.  Swam away strong after release.",
#        ' a patch of white calcerous algae on r supra',
#        ' white patches of calcerous algae on 5th CS and R supra',
#        ' brown algae on neck + shoulders',
#        ' right supra is slightly small',
#        ' a patch of white calcerous algae on RSC',
#        ' net bruises on shoulder',
#        ' few small Bs aligned in the joints of scutes& cutmark on the left side of the plastron',
#        'two healed scratches on 1st and between 3rd and 4th central scutes.',
#        ' green algae on the carapace', ' thin layer of green algae',
#        ' big barnacle on 2nd right lateral scute (removed)',
#        ' tip of the right front flipper is missing',
#        ' patch of calcareous algae on the 3rd central scute and the left supracaudal scute',
#        ' white calcareous algae on carapace', ' flake on first RLS',
#        ' small patches of calcareous algae on carapace',
#        ' barnacles around neck', ' tiny barnacles around the neck',
#        ' light green algaeon carapace',
#        ' few white patches of calcareous algae on scutes',
#        ' 12 MS on both sides',
#        ' small barnacles around the neck and shoulders',
#        ' few barnacles around shoulders and neck',
#        ' tiny barnacles on shoulders',
#        ' barnacles on the neck and shoulders', ' brown algae on carapace',
#        ' some tiny barnacles around the neck',
#        ' brown algae around neck and shoulders',
#        ' light pinkish algae on supras', ' brown algae on neck',
#        ' green algae on shell', ' small barnacles around neck',
#        ' small break on second RLS', ' barnacles on plastron'],
#       dtype=object)

# %%
df['Status'].value_counts()
# Out:
# Status
# Released                                          13610
# Admitted                                            292
# Not_Recorded                                         28
#  shell is beginning to flake                          7
#  green algae on carapace                              7
#                                                   ...
#  barnacles on plastron (removed)                      1
#  notches on RMS                                       1
#  small barnacles around neck and rear flippers        1
#  5 RLS                                                1
#  barnacles on plastron                                1
# Name: count, Length: 439, dtype: int64

# %%
status_nan = df[df['Status'].isna()]
status_nan
# Out:
#           Rescue_ID Date_TimeCaught     Researcher    CaptureSite
# 17     2008_RE_0022      2008-01-23  Researcher_30  CaptureSite_0  \
# 18     2009_RE_0014      2009-01-06  Researcher_30  CaptureSite_0
# 19     2009_RE_0150      2009-02-09  Researcher_30  CaptureSite_0
# 20     2009_RE_0183      2009-02-17  Researcher_30  CaptureSite_0
# 21     2009_RE_0390      2009-06-25  Researcher_30  CaptureSite_0
# ...             ...             ...            ...            ...
# 16291  2011_RE_0805      2011-09-23  Researcher_20  CaptureSite_9
# 16292  2011_RE_0806      2011-09-23  Researcher_20  CaptureSite_9
# 16293  2011_RE_0807      2011-09-23  Researcher_20  CaptureSite_9
# 16294  2011_RE_0809      2011-09-23  Researcher_20  CaptureSite_9
# 16295  2011_RE_0818      2011-09-25  Researcher_20  CaptureSite_9
#
#       ForagingGround CaptureMethod       Fisher
# 17             Ocean           Net   Fisher_257  \
# 18             Ocean       Beached  Fisher_2108
# 19             Ocean       By Hand   Fisher_325
# 20             Ocean       Beached  Fisher_1424
# 21             Ocean           Net  Fisher_1938
# ...              ...           ...          ...
# 16291          Ocean           Net  Fisher_1500
# 16292          Ocean           Net  Fisher_1550
# 16293          Ocean           Net  Fisher_1550
# 16294          Ocean           Net  Fisher_1550
# 16295          Creek           Net  Fisher_1550
#
#                              LandingSite    Species  CCL_cm  CCW_cm
# 17     LandingSite_CaptureSiteCategory_2  Species_5    38.1    38.2  \
# 18     LandingSite_CaptureSiteCategory_2  Species_5    45.6    43.7
# 19     LandingSite_CaptureSiteCategory_2  Species_5    43.4    40.0
# 20     LandingSite_CaptureSiteCategory_2  Species_6    24.7    24.5
# 21     LandingSite_CaptureSiteCategory_2  Species_6    31.0    28.9
# ...                                  ...        ...     ...     ...
# 16291  LandingSite_CaptureSiteCategory_1  Species_6    33.2    30.9
# 16292  LandingSite_CaptureSiteCategory_1  Species_5    43.3    42.1
# 16293  LandingSite_CaptureSiteCategory_1  Species_5   103.4   100.0
# 16294  LandingSite_CaptureSiteCategory_1  Species_5    41.1    38.6
# 16295  LandingSite_CaptureSiteCategory_1  Species_5    96.0    85.4
#
#        Weight_Kg Status
# 17           NaN    NaN
# 18           NaN    NaN
# 19           NaN    NaN
# 20           1.7    NaN
# 21           NaN    NaN
# ...          ...    ...
# 16291        4.5    NaN
# 16292       10.5    NaN
# 16293        NaN    NaN
# 16294        8.5    NaN
# 16295        NaN    NaN
#
# [3633 rows x 13 columns]

# %%
df['ForagingGround'].unique()
# Out:
# array(['Ocean', 'Creek', 'creek'], dtype=object)

# %%
df['CaptureMethod'].unique()
# Out:
# array(['Net', 'Beached', 'Not_Recorded', 'Longline', 'By Hand',
#        'Collected Floater', 'Jarife', 'stranded', 'net', 'Fish Trap',
#        'Uzio', 'Speargun', 'by hand', 'longline', 'jarife'], dtype=object)

# %% [markdown]
# #### ForagingGround and CaptureMethod need case consistency

# %%
df['ForagingGround'] = df['ForagingGround'].str.lower()
df['CaptureMethod'] = df['CaptureMethod'].str.lower()

# %%
df['CaptureMethod'].unique()
# Out:
# array(['net', 'beached', 'not_recorded', 'longline', 'by hand',
#        'collected floater', 'jarife', 'stranded', 'fish trap', 'uzio',
#        'speargun'], dtype=object)

# %%
df['ForagingGround'].unique()
# Out:
# array(['ocean', 'creek'], dtype=object)

# %% [markdown]
# ### Dealing with Missing Values in Length, Width, Weight

# %% [markdown]
# ##### Finding Mean and Median of Length and Width by Species

# %%
df['Species'].value_counts()
# Out:
# Species
# Species_5    11097
# Species_6     6882
# Species_4       50
# Species_7       21
# Species_0        7
# Species_1        2
# Species_2        2
# Species_3        1
# Name: count, dtype: int64

# %%
df.groupby('Species').describe()
# Out:
#             CCL_cm
#              count       mean        std   min     25%    50%     75%     max
# Species
# Species_0      7.0  44.171429  19.973959   2.0  43.750  48.50  53.250   64.70  \
# Species_1      2.0  60.550000  82.802204   2.0  31.275  60.55  89.825  119.10
# Species_2      2.0  43.850000   1.343503  42.9  43.375  43.85  44.325   44.80
# Species_3      1.0  38.500000        NaN  38.5  38.500  38.50  38.500   38.50
# Species_4     50.0  84.579000   7.369168  66.7  80.150  85.10  89.575  102.30
# Species_5  11079.0  46.610660  10.598307   2.0  40.400  43.90  50.300  122.75
# Species_6   6876.0  37.108383   8.044283   3.8  32.500  35.70  39.800   90.50
# Species_7     21.0  43.917619  25.468438   4.0  23.400  52.10  65.000   72.50
#
#             CCW_cm             ...                Weight_Kg
#              count       mean  ...     75%    max     count        mean
# Species                        ...
# Species_0      7.0  41.385714  ...  49.050   58.0       1.0    0.030000  \
# Species_1      2.0  43.250000  ...  63.875   84.5       1.0  121.400000
# Species_2      2.0  43.550000  ...  43.975   44.4       2.0   10.585000
# Species_3      1.0  35.800000  ...  35.800   35.8       1.0    6.600000
# Species_4     50.0  78.853800  ...  82.575   93.8      43.0   76.608605
# Species_5  11076.0  43.799567  ...  46.500  106.0    6415.0   12.432265
# Species_6   6876.0  34.244706  ...  36.800   82.1    6175.0    6.654633
# Species_7     21.0  45.084286  ...  67.800   71.0      15.0   23.506000
#
#
#                  std     min       25%      50%       75%     max
# Species
# Species_0        NaN    0.03    0.0300    0.030    0.0300    0.03
# Species_1        NaN  121.40  121.4000  121.400  121.4000  121.40
# Species_2   0.544472   10.20   10.3925   10.585   10.7775   10.97
# Species_3        NaN    6.60    6.6000    6.600    6.6000    6.60
# Species_4  23.759768    0.03   67.6500   74.810   90.5000  124.80
# Species_5  10.538680    0.03    7.3900    9.500   13.5000  140.00
# Species_6   4.858940    0.02    4.0000    5.350    7.5000   72.00
# Species_7  18.840056    0.10    7.7250   22.360   36.1200   60.95
#
# [8 rows x 24 columns]

# %%
# Group by 'Species' column and calculate average and median for 'CCL_cm' and 'CCW_cm'
species_stats = df.groupby('Species').agg({'CCL_cm': ['mean', 'median'], 'CCW_cm': ['mean', 'median']})

# Rename columns for clarity
species_stats.columns = ['CCL_mean', 'CCL_median', 'CCW_mean', 'CCW_median']

species_stats
# Out:
#             CCL_mean  CCL_median   CCW_mean  CCW_median
# Species
# Species_0  44.171429       48.50  41.385714       45.20
# Species_1  60.550000       60.55  43.250000       43.25
# Species_2  43.850000       43.85  43.550000       43.55
# Species_3  38.500000       38.50  35.800000       35.80
# Species_4  84.579000       85.10  78.853800       78.95
# Species_5  46.610660       43.90  43.799567       41.80
# Species_6  37.108383       35.70  34.244706       33.20
# Species_7  43.917619       52.10  45.084286       54.90

# %%
# Fill NaN values with the mean of each species
df['CCL_cm'] = df.groupby('Species')['CCL_cm'].transform(lambda x: x.fillna(x.mean()))
df['CCW_cm'] = df.groupby('Species')['CCW_cm'].transform(lambda x: x.fillna(x.mean()))
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm                0
# CCW_cm                0
# Weight_Kg          5409
# Status             3633
# dtype: int64

# %% [markdown]
# ### here, I discovered some very large turtles weirdly had tiny weights (0.030kg came up a bunch?)

# %%
df[df['CCW_cm'] > 75]
# Out:
#           Rescue_ID Date_TimeCaught     Researcher    CaptureSite
# 34     2011_RE_0491      2011-06-22  Researcher_20  CaptureSite_0  \
# 75     2016_RE_0393      2016-05-12  Researcher_20  CaptureSite_0
# 121    2008_RE_0441      2008-09-19  Researcher_30  CaptureSite_1
# 122    2008_RE_0444      2008-09-21  Researcher_30  CaptureSite_1
# 127    2008_RE_0518      2008-10-12  Researcher_30  CaptureSite_1
# ...             ...             ...            ...            ...
# 17383  2016_RE_0449      2016-06-10  Researcher_20  CaptureSite_9
# 17474  2016_RE_1132      2016-11-18  Researcher_20  CaptureSite_9
# 17475  2016_RE_1138      2016-11-19  Researcher_20  CaptureSite_9
# 17585  2017_RE_0455      2017-04-09  Researcher_30  CaptureSite_9
# 17647  2017_RE_0769      2017-06-26  Researcher_30  CaptureSite_9
#
#       ForagingGround      CaptureMethod       Fisher
# 34             ocean                net   Fisher_513  \
# 75             ocean            beached    Fisher_44
# 121            ocean                net  Fisher_1550
# 122            ocean                net  Fisher_1550
# 127            ocean                net  Fisher_1757
# ...              ...                ...          ...
# 17383          ocean            beached   Fisher_863
# 17474          ocean             jarife    Fisher_92
# 17475          ocean                net    Fisher_92
# 17585          ocean  collected floater  Fisher_1551
# 17647          ocean                net  Fisher_1921
#
#                              LandingSite    Species  CCL_cm  CCW_cm
# 34     LandingSite_CaptureSiteCategory_2  Species_5    93.4    89.1  \
# 75     LandingSite_CaptureSiteCategory_2  Species_5    97.4    93.2
# 121    LandingSite_CaptureSiteCategory_2  Species_5   101.0    91.4
# 122    LandingSite_CaptureSiteCategory_2  Species_5    92.8    81.5
# 127    LandingSite_CaptureSiteCategory_2  Species_5    99.2    88.7
# ...                                  ...        ...     ...     ...
# 17383  LandingSite_CaptureSiteCategory_1  Species_5    90.0    84.0
# 17474  LandingSite_CaptureSiteCategory_1  Species_5   100.6    95.7
# 17475  LandingSite_CaptureSiteCategory_1  Species_5    83.6    77.9
# 17585  LandingSite_CaptureSiteCategory_1  Species_5   100.0    95.6
# 17647  LandingSite_CaptureSiteCategory_1  Species_5    82.0    75.5
#
#        Weight_Kg                                             Status
# 34         70.00                                                NaN
# 75         93.60                                           Released
# 121          NaN                     no other major characteristics
# 122          NaN   6 LLS& small notch in the joints between both...
# 127          NaN                                                NaN
# ...          ...                                                ...
# 17383      80.80                                           Admitted
# 17474     131.40                                           Released
# 17475      65.20                                           Released
# 17585       0.03                                           Admitted
# 17647      61.00                                           Released
#
# [159 rows x 13 columns]

# %%
df[df['Weight_Kg'] < .1]
# Out:
#           Rescue_ID Date_TimeCaught     Researcher     CaptureSite
# 1083   2016_RE_0423      2016-05-28  Researcher_20  CaptureSite_10  \
# 1335   2018_RE_0387      2018-04-02  Researcher_13  CaptureSite_10
# 2054   2014_RE_0648      2014-07-04  Researcher_20  CaptureSite_12
# 2167   2017_RE_0702      2017-06-13  Researcher_20  CaptureSite_12
# 4908   2017_RE_0548      2017-05-08  Researcher_20  CaptureSite_15
# 6583   2010_RE_0672      2010-08-26  Researcher_30  CaptureSite_19
# 6828   2017_RE_0881      2017-08-06  Researcher_30  CaptureSite_19
# 7739   2012_RE_0776      2012-06-28  Researcher_20  CaptureSite_21
# 10392  2011_RE_0328      2011-05-03  Researcher_20  CaptureSite_24
# 12942  2017_RE_0478      2017-04-19  Researcher_20  CaptureSite_25
# 14586  2017_RE_0846      2017-07-23  Researcher_30   CaptureSite_4
# 17585  2017_RE_0455      2017-04-09  Researcher_30   CaptureSite_9
#
#       ForagingGround      CaptureMethod       Fisher
# 1083           ocean            beached    Fisher_87  \
# 1335           ocean            beached  Fisher_1284
# 2054           ocean            beached   Fisher_264
# 2167           ocean                net  Fisher_1824
# 4908           creek                net    Fisher_92
# 6583           ocean            beached  Fisher_1480
# 6828           ocean                net  Fisher_1901
# 7739           creek                net  Fisher_1115
# 10392          ocean            beached  Fisher_1803
# 12942          creek                net  Fisher_1478
# 14586          ocean           longline  Fisher_1182
# 17585          ocean  collected floater  Fisher_1551
#
#                              LandingSite    Species  CCL_cm  CCW_cm
# 1083   LandingSite_CaptureSiteCategory_2  Species_6     5.7     6.1  \
# 1335   LandingSite_CaptureSiteCategory_2  Species_6     8.1     7.2
# 2054   LandingSite_CaptureSiteCategory_2  Species_6     8.6     8.4
# 2167   LandingSite_CaptureSiteCategory_2  Species_5     6.0     6.0
# 4908   LandingSite_CaptureSiteCategory_0  Species_0     2.0     2.0
# 6583   LandingSite_CaptureSiteCategory_2  Species_5     7.0     6.4
# 6828   LandingSite_CaptureSiteCategory_2  Species_4    87.5    84.5
# 7739   LandingSite_CaptureSiteCategory_0  Species_6     5.9     5.5
# 10392  LandingSite_CaptureSiteCategory_2  Species_6     5.4     5.2
# 12942  LandingSite_CaptureSiteCategory_0  Species_6     6.0     5.6
# 14586  LandingSite_CaptureSiteCategory_2  Species_4    78.6    79.8
# 17585  LandingSite_CaptureSiteCategory_1  Species_5   100.0    95.6
#
#        Weight_Kg                       Status
# 1083        0.03                     Released
# 1335        0.03                     Released
# 2054        0.08                     Released
# 2167        0.05                     Released
# 4908        0.03                     Released
# 6583        0.05                          NaN
# 6828        0.03                     Admitted
# 7739        0.04                     Released
# 10392       0.02                          NaN
# 12942       0.03   tiny barnacles on plastron
# 14586       0.03                     Released
# 17585       0.03                     Admitted

# %%
# Replace 0.03 with NaN in the 'Weight_Kg' column
df['Weight_Kg'].replace(0.03, np.nan, inplace=True)
df[df['Weight_Kg'] == 0.030]
# Out:
# Empty DataFrame
# Columns: [Rescue_ID, Date_TimeCaught, Researcher, CaptureSite, ForagingGround, CaptureMethod, Fisher, LandingSite, Species, CCL_cm, CCW_cm, Weight_Kg, Status]
# Index: []

# %%
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm                0
# CCW_cm                0
# Weight_Kg          5416
# Status             3633
# dtype: int64

# %%
# fill missing weights based on similar lengths and widths within a percentage margin (start 10%?)
def fill_missing_weights3(df, margin=0.10):
    # iterate rows with missing weights
    for index, row in df[df['Weight_Kg'].isnull()].iterrows():
        # lower/upper bounds for length/width
        lower_length = row['CCL_cm'] * (1 - margin)
        upper_length = row['CCL_cm'] * (1 + margin)
        lower_width = row['CCW_cm'] * (1 - margin)
        upper_width = row['CCW_cm'] * (1 + margin)
        
        # store turtles with lengths/widths within margins
        similar_turtles = df[(df['CCL_cm'] >= lower_length) & (df['CCL_cm'] <= upper_length) &
                             (df['CCW_cm'] >= lower_width) & (df['CCW_cm'] <= upper_width) &
                             df['Weight_Kg'].notnull()]
        
        if not similar_turtles.empty:
            # average weight of similar turtles
            avg_weight = similar_turtles['Weight_Kg'].mean()
            # fill missing weight with mean
            df.at[index, 'Weight_Kg'] = avg_weight

fill_missing_weights3(df, margin=0.10)
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm                0
# CCW_cm                0
# Weight_Kg             6
# Status             3633
# dtype: int64

# %%
fill_missing_weights3(df, margin=0.20)
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm                0
# CCW_cm                0
# Weight_Kg             3
# Status             3633
# dtype: int64

# %%
df[df['Weight_Kg'].isnull()]
# Out:
#          Rescue_ID Date_TimeCaught     Researcher     CaptureSite
# 4908  2017_RE_0548      2017-05-08  Researcher_20  CaptureSite_15  \
# 6962  2008_RE_0007      2008-01-06  Researcher_10   CaptureSite_2
# 8580  2003_RE_0545      2003-06-26  Researcher_30  CaptureSite_23
#
#      ForagingGround CaptureMethod       Fisher
# 4908          creek           net    Fisher_92  \
# 6962          ocean           net  Fisher_1757
# 8580          creek           net  Fisher_1909
#
#                             LandingSite    Species  CCL_cm  CCW_cm  Weight_Kg
# 4908  LandingSite_CaptureSiteCategory_0  Species_0     2.0     2.0        NaN  \
# 6962  LandingSite_CaptureSiteCategory_2  Species_5     2.0     2.0        NaN
# 8580  LandingSite_CaptureSiteCategory_0  Species_1     2.0     2.0        NaN
#
#         Status
# 4908  Released
# 6962       NaN
# 8580  Released

# %%
df[df['CCW_cm'] < 4]
# Out:
#          Rescue_ID Date_TimeCaught     Researcher     CaptureSite
# 914   2002_RE_0058      2002-05-11  Researcher_32  CaptureSite_10  \
# 1597  2015_RE_0847      2015-07-15  Researcher_20  CaptureSite_11
# 1598  2015_RE_0848      2015-07-15  Researcher_20  CaptureSite_11
# 4908  2017_RE_0548      2017-05-08  Researcher_20  CaptureSite_15
# 6962  2008_RE_0007      2008-01-06  Researcher_10   CaptureSite_2
# 8580  2003_RE_0545      2003-06-26  Researcher_30  CaptureSite_23
# 9989  2015_RE_0846      2015-07-14  Researcher_20  CaptureSite_23
#
#      ForagingGround CaptureMethod       Fisher
# 914           ocean           net   Fisher_662  \
# 1597          creek           net  Fisher_1478
# 1598          creek           net  Fisher_1478
# 4908          creek           net    Fisher_92
# 6962          ocean           net  Fisher_1757
# 8580          creek           net  Fisher_1909
# 9989          creek           net  Fisher_1108
#
#                             LandingSite    Species  CCL_cm  CCW_cm  Weight_Kg
# 914   LandingSite_CaptureSiteCategory_2  Species_6     3.8     3.6   0.268308  \
# 1597  LandingSite_CaptureSiteCategory_0  Species_5     4.3     3.6   0.100000
# 1598  LandingSite_CaptureSiteCategory_0  Species_5     4.6     3.6   0.100000
# 4908  LandingSite_CaptureSiteCategory_0  Species_0     2.0     2.0        NaN
# 6962  LandingSite_CaptureSiteCategory_2  Species_5     2.0     2.0        NaN
# 8580  LandingSite_CaptureSiteCategory_0  Species_1     2.0     2.0        NaN
# 9989  LandingSite_CaptureSiteCategory_0  Species_5     4.3     3.5   0.100000
#
#         Status
# 914   Released
# 1597  Released
# 1598  Released
# 4908  Released
# 6962       NaN
# 8580  Released
# 9989  Released

# %%
# Replace missing weight values with 0.08
df.loc[df['Weight_Kg'].isnull(), 'Weight_Kg'] = 0.08
df.isna().sum()
# Out:
# Rescue_ID             0
# Date_TimeCaught       0
# Researcher            0
# CaptureSite           0
# ForagingGround        0
# CaptureMethod         0
# Fisher                0
# LandingSite           0
# Species               0
# CCL_cm                0
# CCW_cm                0
# Weight_Kg             0
# Status             3633
# dtype: int64

# %% [markdown]
# ## Considering the Date/Time Column
# Deciding that Month is specific enough, to drop individual dates, so a column for year and a column for month is fine to me

# %%
df['Date_TimeCaught']
# Out:
# 0        2000-12-22
# 1        2001-10-28
# 2        2001-11-01
# 3        2002-03-11
# 4        2002-08-08
#             ...
# 18057    2018-12-18
# 18058    2018-12-18
# 18059    2018-12-24
# 18060    2018-12-24
# 18061    2018-12-28
# Name: Date_TimeCaught, Length: 18062, dtype: object

# %%
df['Date_TimeCaught'].dtype
# Out:
# dtype('O')

# %%
# extract year and month from 'Date_TimeCaught' column (formatted as string!)
df['year_caught'] = df['Date_TimeCaught'].str[:4].astype(int)
df['month_caught'] = df['Date_TimeCaught'].str[5:7].astype(int)

df
# Out:
#           Rescue_ID Date_TimeCaught     Researcher    CaptureSite
# 0      2000_RE_0060      2000-12-22  Researcher_25  CaptureSite_0  \
# 1      2001_RE_0187      2001-10-28   Researcher_6  CaptureSite_0
# 2      2001_RE_0197      2001-11-01   Researcher_6  CaptureSite_0
# 3      2002_RE_0031      2002-03-11  Researcher_32  CaptureSite_0
# 4      2002_RE_0118      2002-08-08  Researcher_25  CaptureSite_0
# ...             ...             ...            ...            ...
# 18057  2018_RE_1511      2018-12-18  Researcher_30  CaptureSite_9
# 18058  2018_RE_1514      2018-12-18  Researcher_30  CaptureSite_9
# 18059  2018_RE_1532      2018-12-24  Researcher_30  CaptureSite_9
# 18060  2018_RE_1533      2018-12-24  Researcher_30  CaptureSite_9
# 18061  2018_RE_1550      2018-12-28  Researcher_30  CaptureSite_9
#
#       ForagingGround CaptureMethod       Fisher
# 0              ocean           net  Fisher_1072  \
# 1              ocean           net   Fisher_520
# 2              ocean           net  Fisher_1669
# 3              ocean           net  Fisher_1798
# 4              ocean       beached  Fisher_1918
# ...              ...           ...          ...
# 18057          ocean           net   Fisher_569
# 18058          ocean           net   Fisher_125
# 18059          ocean           net  Fisher_1343
# 18060          ocean           net  Fisher_1551
# 18061          ocean           net  Fisher_1551
#
#                              LandingSite    Species  CCL_cm  CCW_cm
# 0      LandingSite_CaptureSiteCategory_2  Species_6   64.70   62.60  \
# 1      LandingSite_CaptureSiteCategory_2  Species_6   35.85   31.35
# 2      LandingSite_CaptureSiteCategory_2  Species_5   51.80   49.20
# 3      LandingSite_CaptureSiteCategory_2  Species_6   60.50   59.00
# 4      LandingSite_CaptureSiteCategory_2  Species_5   34.70   33.00
# ...                                  ...        ...     ...     ...
# 18057  LandingSite_CaptureSiteCategory_1  Species_5   57.13   50.57
# 18058  LandingSite_CaptureSiteCategory_1  Species_6   42.07   38.37
# 18059  LandingSite_CaptureSiteCategory_1  Species_5   57.20   52.30
# 18060  LandingSite_CaptureSiteCategory_1  Species_5   51.90   48.50
# 18061  LandingSite_CaptureSiteCategory_1  Species_6   34.60   31.20
#
#        Weight_Kg    Status  year_caught  month_caught
# 0      32.262274  Released         2000            12
# 1       5.014822  Released         2001            10
# 2      16.349537  Released         2001            11
# 3      27.349175  Released         2002             3
# 4       5.206052  Released         2002             8
# ...          ...       ...          ...           ...
# 18057  21.090000  Released         2018            12
# 18058   9.020000  Released         2018            12
# 18059  20.461698  Released         2018            12
# 18060  15.618496  Released         2018            12
# 18061   4.290000  Released         2018            12
#
# [18062 rows x 15 columns]

# %%
df['Fisher'].value_counts()
# Out:
# Fisher
# Fisher_1478    1499
# Fisher_92       570
# Fisher_1550     448
# Fisher_1551     435
# Fisher_1472     383
#                ...
# Fisher_611        1
# Fisher_408        1
# Fisher_107        1
# Fisher_294        1
# Fisher_569        1
# Name: count, Length: 2085, dtype: int64

# %% [markdown]
# ### Further consolidating data, dropping other columns, merging length/width

# %% [markdown]
# deciding to drop Rescue_ID, CaptureMethod, Researcher and now we no longer need Species

# %%
columns_drop = ['Species', 'Rescue_ID', 'CaptureMethod', 'Researcher']
df.drop(columns=columns_drop, inplace=True)
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                              LandingSite  CCL_cm  CCW_cm  Weight_Kg    Status
# 0      LandingSite_CaptureSiteCategory_2   64.70   62.60  32.262274  Released  \
# 1      LandingSite_CaptureSiteCategory_2   35.85   31.35   5.014822  Released
# 2      LandingSite_CaptureSiteCategory_2   51.80   49.20  16.349537  Released
# 3      LandingSite_CaptureSiteCategory_2   60.50   59.00  27.349175  Released
# 4      LandingSite_CaptureSiteCategory_2   34.70   33.00   5.206052  Released
# ...                                  ...     ...     ...        ...       ...
# 18057  LandingSite_CaptureSiteCategory_1   57.13   50.57  21.090000  Released
# 18058  LandingSite_CaptureSiteCategory_1   42.07   38.37   9.020000  Released
# 18059  LandingSite_CaptureSiteCategory_1   57.20   52.30  20.461698  Released
# 18060  LandingSite_CaptureSiteCategory_1   51.90   48.50  15.618496  Released
# 18061  LandingSite_CaptureSiteCategory_1   34.60   31.20   4.290000  Released
#
#        year_caught  month_caught
# 0             2000            12
# 1             2001            10
# 2             2001            11
# 3             2002             3
# 4             2002             8
# ...            ...           ...
# 18057         2018            12
# 18058         2018            12
# 18059         2018            12
# 18060         2018            12
# 18061         2018            12
#
# [18062 rows x 11 columns]

# %%
# Calculate area from CCL_cm and CCW_cm
df['area_sqcm'] = (df['CCL_cm'] * df['CCW_cm']) / 100

# Drop the original columns
df.drop(['CCL_cm', 'CCW_cm'], axis=1, inplace=True)
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                              LandingSite  Weight_Kg    Status  year_caught
# 0      LandingSite_CaptureSiteCategory_2  32.262274  Released         2000  \
# 1      LandingSite_CaptureSiteCategory_2   5.014822  Released         2001
# 2      LandingSite_CaptureSiteCategory_2  16.349537  Released         2001
# 3      LandingSite_CaptureSiteCategory_2  27.349175  Released         2002
# 4      LandingSite_CaptureSiteCategory_2   5.206052  Released         2002
# ...                                  ...        ...       ...          ...
# 18057  LandingSite_CaptureSiteCategory_1  21.090000  Released         2018
# 18058  LandingSite_CaptureSiteCategory_1   9.020000  Released         2018
# 18059  LandingSite_CaptureSiteCategory_1  20.461698  Released         2018
# 18060  LandingSite_CaptureSiteCategory_1  15.618496  Released         2018
# 18061  LandingSite_CaptureSiteCategory_1   4.290000  Released         2018
#
#        month_caught  area_sqcm
# 0                12  40.502200
# 1                10  11.238975
# 2                11  25.485600
# 3                 3  35.695000
# 4                 8  11.451000
# ...             ...        ...
# 18057            12  28.890641
# 18058            12  16.142259
# 18059            12  29.915600
# 18060            12  25.171500
# 18061            12  10.795200
#
# [18062 rows x 10 columns]

# %% [markdown]
# <a id="2nd-table"></a>

# %% [markdown]
# ## Exploring CaptureSite_category.csv to see if Category means LandingSite and Type means ForagingGround Type

# %%
# Loading the titanic dataset
csc = pd.read_csv('data/CaptureSite_category.csv')
csc
# Out:
#        CaptureSite    CaptureSiteCategory    Type
# 0    CaptureSite_0  CaptureSiteCategory_2  Type_1
# 1    CaptureSite_1  CaptureSiteCategory_2  Type_1
# 2   CaptureSite_10  CaptureSiteCategory_2  Type_1
# 3   CaptureSite_11  CaptureSiteCategory_0  Type_0
# 4   CaptureSite_12  CaptureSiteCategory_2  Type_1
# 5   CaptureSite_13  CaptureSiteCategory_2  Type_1
# 6   CaptureSite_14  CaptureSiteCategory_4  Type_0
# 7   CaptureSite_15  CaptureSiteCategory_0  Type_0
# 8   CaptureSite_16  CaptureSiteCategory_4  Type_0
# 9   CaptureSite_17  CaptureSiteCategory_4  Type_0
# 10  CaptureSite_18  CaptureSiteCategory_1  Type_1
# 11  CaptureSite_19  CaptureSiteCategory_2  Type_1
# 12   CaptureSite_2  CaptureSiteCategory_2  Type_1
# 13  CaptureSite_20  CaptureSiteCategory_0  Type_0
# 14  CaptureSite_21  CaptureSiteCategory_0  Type_0
# 15  CaptureSite_22  CaptureSiteCategory_4  Type_0
# 16  CaptureSite_23  CaptureSiteCategory_0  Type_0
# 17  CaptureSite_24  CaptureSiteCategory_2  Type_1
# 18  CaptureSite_25  CaptureSiteCategory_0  Type_0
# 19  CaptureSite_26  CaptureSiteCategory_3  Type_1
# 20  CaptureSite_27  CaptureSiteCategory_0  Type_0
# 21  CaptureSite_28  CaptureSiteCategory_0  Type_0
# 22   CaptureSite_3  CaptureSiteCategory_2  Type_1
# 23   CaptureSite_4  CaptureSiteCategory_2  Type_1
# 24   CaptureSite_5  CaptureSiteCategory_4  Type_0
# 25   CaptureSite_6  CaptureSiteCategory_4  Type_0
# 26   CaptureSite_7  CaptureSiteCategory_4  Type_0
# 27   CaptureSite_8  CaptureSiteCategory_1  Type_1
# 28   CaptureSite_9  CaptureSiteCategory_1  Type_1

# %%
# Merge 'df' with 'csc' on the 'CaptureSite' column
df = df.merge(csc[['CaptureSite', 'CaptureSiteCategory', 'Type']], on='CaptureSite', how='left')

# %%
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                              LandingSite  Weight_Kg    Status  year_caught
# 0      LandingSite_CaptureSiteCategory_2  32.262274  Released         2000  \
# 1      LandingSite_CaptureSiteCategory_2   5.014822  Released         2001
# 2      LandingSite_CaptureSiteCategory_2  16.349537  Released         2001
# 3      LandingSite_CaptureSiteCategory_2  27.349175  Released         2002
# 4      LandingSite_CaptureSiteCategory_2   5.206052  Released         2002
# ...                                  ...        ...       ...          ...
# 18057  LandingSite_CaptureSiteCategory_1  21.090000  Released         2018
# 18058  LandingSite_CaptureSiteCategory_1   9.020000  Released         2018
# 18059  LandingSite_CaptureSiteCategory_1  20.461698  Released         2018
# 18060  LandingSite_CaptureSiteCategory_1  15.618496  Released         2018
# 18061  LandingSite_CaptureSiteCategory_1   4.290000  Released         2018
#
#        month_caught  area_sqcm    CaptureSiteCategory    Type
# 0                12  40.502200  CaptureSiteCategory_2  Type_1
# 1                10  11.238975  CaptureSiteCategory_2  Type_1
# 2                11  25.485600  CaptureSiteCategory_2  Type_1
# 3                 3  35.695000  CaptureSiteCategory_2  Type_1
# 4                 8  11.451000  CaptureSiteCategory_2  Type_1
# ...             ...        ...                    ...     ...
# 18057            12  28.890641  CaptureSiteCategory_1  Type_1
# 18058            12  16.142259  CaptureSiteCategory_1  Type_1
# 18059            12  29.915600  CaptureSiteCategory_1  Type_1
# 18060            12  25.171500  CaptureSiteCategory_1  Type_1
# 18061            12  10.795200  CaptureSiteCategory_1  Type_1
#
# [18062 rows x 12 columns]

# %%
# Replace the prefix "LandingSite_" with an empty string in the 'LandingSite' column
df['LandingSite'] = df['LandingSite'].str.replace('LandingSite_', '')
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 0      CaptureSiteCategory_2  32.262274  Released         2000            12  \
# 1      CaptureSiteCategory_2   5.014822  Released         2001            10
# 2      CaptureSiteCategory_2  16.349537  Released         2001            11
# 3      CaptureSiteCategory_2  27.349175  Released         2002             3
# 4      CaptureSiteCategory_2   5.206052  Released         2002             8
# ...                      ...        ...       ...          ...           ...
# 18057  CaptureSiteCategory_1  21.090000  Released         2018            12
# 18058  CaptureSiteCategory_1   9.020000  Released         2018            12
# 18059  CaptureSiteCategory_1  20.461698  Released         2018            12
# 18060  CaptureSiteCategory_1  15.618496  Released         2018            12
# 18061  CaptureSiteCategory_1   4.290000  Released         2018            12
#
#        area_sqcm    CaptureSiteCategory    Type
# 0      40.502200  CaptureSiteCategory_2  Type_1
# 1      11.238975  CaptureSiteCategory_2  Type_1
# 2      25.485600  CaptureSiteCategory_2  Type_1
# 3      35.695000  CaptureSiteCategory_2  Type_1
# 4      11.451000  CaptureSiteCategory_2  Type_1
# ...          ...                    ...     ...
# 18057  28.890641  CaptureSiteCategory_1  Type_1
# 18058  16.142259  CaptureSiteCategory_1  Type_1
# 18059  29.915600  CaptureSiteCategory_1  Type_1
# 18060  25.171500  CaptureSiteCategory_1  Type_1
# 18061  10.795200  CaptureSiteCategory_1  Type_1
#
# [18062 rows x 12 columns]

# %%
# Create a new DataFrame to store rows with different values in 'LandingSite' and 'CaptureSiteCategory'
different_sites_df = df[df['LandingSite'] != df['CaptureSiteCategory']]
different_sites_df
# Out:
# Empty DataFrame
# Columns: [Date_TimeCaught, CaptureSite, ForagingGround, Fisher, LandingSite, Weight_Kg, Status, year_caught, month_caught, area_sqcm, CaptureSiteCategory, Type]
# Index: []

# %% [markdown]
# ### Landing Site and Capture Site Category are synonymous!!

# %%
df.drop('CaptureSiteCategory', axis=1, inplace=True)
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 0      CaptureSiteCategory_2  32.262274  Released         2000            12  \
# 1      CaptureSiteCategory_2   5.014822  Released         2001            10
# 2      CaptureSiteCategory_2  16.349537  Released         2001            11
# 3      CaptureSiteCategory_2  27.349175  Released         2002             3
# 4      CaptureSiteCategory_2   5.206052  Released         2002             8
# ...                      ...        ...       ...          ...           ...
# 18057  CaptureSiteCategory_1  21.090000  Released         2018            12
# 18058  CaptureSiteCategory_1   9.020000  Released         2018            12
# 18059  CaptureSiteCategory_1  20.461698  Released         2018            12
# 18060  CaptureSiteCategory_1  15.618496  Released         2018            12
# 18061  CaptureSiteCategory_1   4.290000  Released         2018            12
#
#        area_sqcm    Type
# 0      40.502200  Type_1
# 1      11.238975  Type_1
# 2      25.485600  Type_1
# 3      35.695000  Type_1
# 4      11.451000  Type_1
# ...          ...     ...
# 18057  28.890641  Type_1
# 18058  16.142259  Type_1
# 18059  29.915600  Type_1
# 18060  25.171500  Type_1
# 18061  10.795200  Type_1
#
# [18062 rows x 11 columns]

# %%
# Filter rows where 'ForagingGround' is 'ocean' and 'Type' is 0 or 1
ocean_df = df[(df['ForagingGround'] == 'ocean') & (df['Type'] == 'Type_0')]

# Filter rows where 'ForagingGround' is 'creek' and 'Type' is 0 or 1
creek_df = df[(df['ForagingGround'] == 'creek') & (df['Type'] == 'Type_0')]

# Filter rows where 'ForagingGround' is 'ocean' and 'Type' is 0 or 1
ocean_df1 = df[(df['ForagingGround'] == 'ocean') & (df['Type'] == 'Type_1')]

# Filter rows where 'ForagingGround' is 'creek' and 'Type' is 0 or 1
creek_df1 = df[(df['ForagingGround'] == 'creek') & (df['Type'] == 'Type_1')]

# Print the DataFrames
print("Rows with 'ocean' ForagingGround and Type 0:")
ocean_df
# Out:
# Rows with 'ocean' ForagingGround and Type 0:
#       Date_TimeCaught     CaptureSite ForagingGround       Fisher
# 1631       2016-10-22  CaptureSite_11          ocean  Fisher_1108  \
# 3077       2003-02-14  CaptureSite_14          ocean    Fisher_92
# 3078       2003-04-02  CaptureSite_14          ocean   Fisher_710
# 3079       2003-04-18  CaptureSite_14          ocean   Fisher_881
# 3080       2003-04-24  CaptureSite_14          ocean    Fisher_94
# ...               ...             ...            ...          ...
# 15297      2013-02-05   CaptureSite_6          ocean    Fisher_79
# 15305      2013-08-16   CaptureSite_6          ocean  Fisher_1085
# 15636      2012-02-04   CaptureSite_7          ocean  Fisher_2091
# 15740      2017-05-13   CaptureSite_7          ocean  Fisher_1472
# 15750      2017-11-09   CaptureSite_7          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 1631   CaptureSiteCategory_0  46.000000  Released         2016            10  \
# 3077   CaptureSiteCategory_4   8.192073  Released         2003             2
# 3078   CaptureSiteCategory_4   2.535918  Released         2003             4
# 3079   CaptureSiteCategory_4   4.508567  Released         2003             4
# 3080   CaptureSiteCategory_4  10.678913  Released         2003             4
# ...                      ...        ...       ...          ...           ...
# 15297  CaptureSiteCategory_4   5.300000  Released         2013             2
# 15305  CaptureSiteCategory_4   6.000000  Released         2013             8
# 15636  CaptureSiteCategory_4   8.500000  Released         2012             2
# 15740  CaptureSiteCategory_4   7.880000  Released         2017             5
# 15750  CaptureSiteCategory_4   6.710000  Released         2017            11
#
#        area_sqcm    Type
# 1631     44.4500  Type_0
# 3077     15.9039  Type_0
# 3078      0.2548  Type_0
# 3079     10.1970  Type_0
# 3080     19.5794  Type_0
# ...          ...     ...
# 15297    14.0040  Type_0
# 15305    11.4240  Type_0
# 15636    15.2448  Type_0
# 15740    15.0590  Type_0
# 15750    13.4365  Type_0
#
# [92 rows x 11 columns]

# %%
print("Rows with 'ocean' ForagingGround and Type 1:")
ocean_df1
# Out:
# Rows with 'ocean' ForagingGround and Type 1:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 0      CaptureSiteCategory_2  32.262274  Released         2000            12  \
# 1      CaptureSiteCategory_2   5.014822  Released         2001            10
# 2      CaptureSiteCategory_2  16.349537  Released         2001            11
# 3      CaptureSiteCategory_2  27.349175  Released         2002             3
# 4      CaptureSiteCategory_2   5.206052  Released         2002             8
# ...                      ...        ...       ...          ...           ...
# 18057  CaptureSiteCategory_1  21.090000  Released         2018            12
# 18058  CaptureSiteCategory_1   9.020000  Released         2018            12
# 18059  CaptureSiteCategory_1  20.461698  Released         2018            12
# 18060  CaptureSiteCategory_1  15.618496  Released         2018            12
# 18061  CaptureSiteCategory_1   4.290000  Released         2018            12
#
#        area_sqcm    Type
# 0      40.502200  Type_1
# 1      11.238975  Type_1
# 2      25.485600  Type_1
# 3      35.695000  Type_1
# 4      11.451000  Type_1
# ...          ...     ...
# 18057  28.890641  Type_1
# 18058  16.142259  Type_1
# 18059  29.915600  Type_1
# 18060  25.171500  Type_1
# 18061  10.795200  Type_1
#
# [6559 rows x 11 columns]

# %%
print("\nRows with 'creek' ForagingGround and Type 0:")
creek_df
# Out:
# Rows with 'creek' ForagingGround and Type 0:
#       Date_TimeCaught     CaptureSite ForagingGround       Fisher
# 1352       1998-07-07  CaptureSite_11          creek  Fisher_1235  \
# 1353       1998-08-03  CaptureSite_11          creek   Fisher_835
# 1354       1998-09-25  CaptureSite_11          creek  Fisher_1208
# 1355       1998-09-26  CaptureSite_11          creek   Fisher_155
# 1356       1998-10-20  CaptureSite_11          creek  Fisher_1716
# ...               ...             ...            ...          ...
# 15774      2018-11-14   CaptureSite_7          creek  Fisher_1478
# 15775      2018-11-14   CaptureSite_7          creek  Fisher_1478
# 15776      2018-11-17   CaptureSite_7          creek   Fisher_475
# 15777      2018-11-26   CaptureSite_7          creek  Fisher_1244
# 15778      2018-12-28   CaptureSite_7          creek   Fisher_507
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 1352   CaptureSiteCategory_0  10.293180       NaN         1998             7  \
# 1353   CaptureSiteCategory_0   7.810512  Released         1998             8
# 1354   CaptureSiteCategory_0  35.080970  Released         1998             9
# 1355   CaptureSiteCategory_0   4.584281  Released         1998             9
# 1356   CaptureSiteCategory_0  11.531251  Released         1998            10
# ...                      ...        ...       ...          ...           ...
# 15774  CaptureSiteCategory_4  12.300000  Released         2018            11
# 15775  CaptureSiteCategory_4   7.730000  Released         2018            11
# 15776  CaptureSiteCategory_4   4.900000  Released         2018            11
# 15777  CaptureSiteCategory_4  20.800000  Released         2018            11
# 15778  CaptureSiteCategory_4  11.350000  Released         2018            12
#
#        area_sqcm    Type
# 1352   17.774158  Type_0
# 1353   14.668500  Type_0
# 1354   43.548300  Type_0
# 1355   10.458450  Type_0
# 1356   20.294600  Type_0
# ...          ...     ...
# 15774  20.728209  Type_0
# 15775  15.884700  Type_0
# 15776  11.857621  Type_0
# 15777  26.910639  Type_0
# 15778  19.403800  Type_0
#
# [11323 rows x 11 columns]

# %%
print("Rows with 'creek' ForagingGround and Type 1:")
creek_df1
# Out:
# Rows with 'creek' ForagingGround and Type 1:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 45         2014-05-28  CaptureSite_0          creek  Fisher_1841  \
# 259        2011-04-28  CaptureSite_1          creek   Fisher_863
# 339        2012-02-16  CaptureSite_1          creek   Fisher_603
# 425        2012-10-29  CaptureSite_1          creek    Fisher_92
# 469        2013-03-05  CaptureSite_1          creek   Fisher_899
# ...               ...            ...            ...          ...
# 17703      2017-10-11  CaptureSite_9          creek  Fisher_1472
# 17704      2017-10-11  CaptureSite_9          creek  Fisher_1551
# 17795      2018-01-11  CaptureSite_9          creek  Fisher_1551
# 17796      2018-01-12  CaptureSite_9          creek  Fisher_1058
# 17811      2018-01-28  CaptureSite_9          creek   Fisher_915
#
#                  LandingSite  Weight_Kg    Status  year_caught  month_caught
# 45     CaptureSiteCategory_2       5.92  Released         2014             5  \
# 259    CaptureSiteCategory_2      12.50       NaN         2011             4
# 339    CaptureSiteCategory_2       7.50  Released         2012             2
# 425    CaptureSiteCategory_2       6.70  Released         2012            10
# 469    CaptureSiteCategory_2       8.60  Released         2013             3
# ...                      ...        ...       ...          ...           ...
# 17703  CaptureSiteCategory_1      13.36  Released         2017            10
# 17704  CaptureSiteCategory_1       3.56  Released         2017            10
# 17795  CaptureSiteCategory_1       6.97  Released         2018             1
# 17796  CaptureSiteCategory_1       7.57  Released         2018             1
# 17811  CaptureSiteCategory_1       5.85  Released         2018             1
#
#        area_sqcm    Type
# 45      13.24600  Type_1
# 259     19.47120  Type_1
# 339     15.04000  Type_1
# 425     15.66200  Type_1
# 469     16.18960  Type_1
# ...          ...     ...
# 17703   21.12000  Type_1
# 17704    8.91000  Type_1
# 17795   14.15700  Type_1
# 17796   15.48420  Type_1
# 17811   13.53129  Type_1
#
# [88 rows x 11 columns]

# %% [markdown]
# ### there is no connection between capture site type and foraging ground

# %% [markdown]
# ### Just caught that they want the results to be predictions per site per week of year
# ##### I found some code to get the week of year from the DateTime info in the original csv

# %%
# Create Time features from Date_TimeCaught 
df["Date_TimeCaught"] = pd.to_datetime(df["Date_TimeCaught"])
df["year"] = df["Date_TimeCaught"].dt.year
df["month"] = df["Date_TimeCaught"].dt.month
df["week_of_year"] = df["Date_TimeCaught"].dt.isocalendar().week

# Custom function to adjust year_woy column
def adjust_year_woy(row):
    if row["week_of_year"] == 53:
        if row["month"] == 12:  # December date
            return row["year"] * 100 + row["week_of_year"]
        elif row["month"] == 1:  # January date
            return (row["year"] - 1) * 100 + '_' + row["week_of_year"]
    else:
        return row["year"] * 100 + row["week_of_year"]

# Apply the custom function to create the year_woy column
df["year_woy"] = df.apply(adjust_year_woy, axis=1)
df.head()
# Out:
#   Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0      2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1      2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2      2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3      2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4      2002-08-08  CaptureSite_0          ocean  Fisher_1918
#
#              LandingSite  Weight_Kg    Status  year_caught  month_caught
# 0  CaptureSiteCategory_2  32.262274  Released         2000            12  \
# 1  CaptureSiteCategory_2   5.014822  Released         2001            10
# 2  CaptureSiteCategory_2  16.349537  Released         2001            11
# 3  CaptureSiteCategory_2  27.349175  Released         2002             3
# 4  CaptureSiteCategory_2   5.206052  Released         2002             8
#
#    area_sqcm    Type  year  month  week_of_year  year_woy
# 0  40.502200  Type_1  2000     12            51    200051
# 1  11.238975  Type_1  2001     10            43    200143
# 2  25.485600  Type_1  2001     11            44    200144
# 3  35.695000  Type_1  2002      3            11    200211
# 4  11.451000  Type_1  2002      8            32    200232

# %%
df.drop(['year_caught', 'month_caught'], axis=1, inplace=True)
df
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 0          2000-12-22  CaptureSite_0          ocean  Fisher_1072  \
# 1          2001-10-28  CaptureSite_0          ocean   Fisher_520
# 2          2001-11-01  CaptureSite_0          ocean  Fisher_1669
# 3          2002-03-11  CaptureSite_0          ocean  Fisher_1798
# 4          2002-08-08  CaptureSite_0          ocean  Fisher_1918
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 0      CaptureSiteCategory_2  32.262274  Released  40.502200  Type_1  2000  \
# 1      CaptureSiteCategory_2   5.014822  Released  11.238975  Type_1  2001
# 2      CaptureSiteCategory_2  16.349537  Released  25.485600  Type_1  2001
# 3      CaptureSiteCategory_2  27.349175  Released  35.695000  Type_1  2002
# 4      CaptureSiteCategory_2   5.206052  Released  11.451000  Type_1  2002
# ...                      ...        ...       ...        ...     ...   ...
# 18057  CaptureSiteCategory_1  21.090000  Released  28.890641  Type_1  2018
# 18058  CaptureSiteCategory_1   9.020000  Released  16.142259  Type_1  2018
# 18059  CaptureSiteCategory_1  20.461698  Released  29.915600  Type_1  2018
# 18060  CaptureSiteCategory_1  15.618496  Released  25.171500  Type_1  2018
# 18061  CaptureSiteCategory_1   4.290000  Released  10.795200  Type_1  2018
#
#        month  week_of_year  year_woy
# 0         12            51    200051
# 1         10            43    200143
# 2         11            44    200144
# 3          3            11    200211
# 4          8            32    200232
# ...      ...           ...       ...
# 18057     12            51    201851
# 18058     12            51    201851
# 18059     12            52    201852
# 18060     12            52    201852
# 18061     12            52    201852
#
# [18062 rows x 13 columns]

# %%
df[df['week_of_year'] == 53]
# Out:
#       Date_TimeCaught     CaptureSite ForagingGround       Fisher
# 752        2015-12-31   CaptureSite_1          ocean    Fisher_92  \
# 753        2016-01-03   CaptureSite_1          ocean   Fisher_818
# 1526       2009-12-30  CaptureSite_11          creek   Fisher_876
# 1527       2010-01-01  CaptureSite_11          creek   Fisher_664
# 1913       2010-01-03  CaptureSite_12          ocean   Fisher_959
# ...               ...             ...            ...          ...
# 17324      2015-12-28   CaptureSite_9          ocean  Fisher_1027
# 17325      2015-12-30   CaptureSite_9          ocean  Fisher_1115
# 17326      2015-12-31   CaptureSite_9          ocean  Fisher_1473
# 17327      2016-01-01   CaptureSite_9          ocean   Fisher_603
# 17328      2016-01-03   CaptureSite_9          ocean   Fisher_351
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 752    CaptureSiteCategory_2   4.250000  Released     9.7500  Type_1  2015  \
# 753    CaptureSiteCategory_2   7.040000  Released    12.7939  Type_1  2016
# 1526   CaptureSiteCategory_0   9.612136       NaN    18.0525  Type_0  2009
# 1527   CaptureSiteCategory_0   5.750806       NaN    12.3137  Type_0  2010
# 1913   CaptureSiteCategory_2   7.079806       NaN    14.2803  Type_1  2010
# ...                      ...        ...       ...        ...     ...   ...
# 17324  CaptureSiteCategory_1   4.300000  Released     8.1090  Type_1  2015
# 17325  CaptureSiteCategory_1   4.860000  Released    11.0565  Type_1  2015
# 17326  CaptureSiteCategory_1   5.750000  Released    12.8340  Type_1  2015
# 17327  CaptureSiteCategory_1   8.940000  Released    15.0626  Type_1  2016
# 17328  CaptureSiteCategory_1   7.780000  Released    14.1570  Type_1  2016
#
#        month  week_of_year  year_woy
# 752       12            53    201553
# 753        1            53    201553
# 1526      12            53    200953
# 1527       1            53    200953
# 1913       1            53    200953
# ...      ...           ...       ...
# 17324     12            53    201553
# 17325     12            53    201553
# 17326     12            53    201553
# 17327      1            53    201553
# 17328      1            53    201553
#
# [63 rows x 13 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# First, some simple graphs showing the number of captures by year and month

# %%
df['year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2008, 2009, 2010, 2011, 2012, 2014,
#        2015, 2016, 2017, 2018, 2006, 2013, 2005, 2007, 1998, 1999],
#       dtype=int32)

# %%
df['month'].unique()
# Out:
# array([12, 10, 11,  3,  8,  6,  9,  1,  2,  7,  4,  5], dtype=int32)

# %%
df['week_of_year'].unique()
# Out:
# <IntegerArray>
# [51, 43, 44, 11, 32, 24, 33, 36, 39, 42,  4,  2,  7,  8, 26, 29, 16, 38, 46,
#  25, 34, 17, 19, 23, 22, 30, 35, 37, 45, 50, 52,  3, 10, 40, 12, 49,  1, 14,
#   5, 41, 48, 20, 28, 31, 47,  6,  9, 15, 27, 21, 13, 18, 53]
# Length: 53, dtype: UInt32

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='month', data=df, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Month')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='year', data=df, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Year')  # Set the title of the plot
plt.xlabel('Year')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.show()

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Create the count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='month', data=df_filtered, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Month (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.show()

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Create the count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='week_of_year', data=df_filtered, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Week of Year (2011 or Later)')  # Set the title of the plot
plt.xlabel('Week of Year')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.show()

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Create the count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='CaptureSite', data=df_filtered, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Site')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)
plt.show()

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Create the count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='LandingSite', data=df_filtered, palette='viridis')  # Create the count plot
plt.title('Number of Captures by Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Landing Site')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)
plt.show()

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Pivot the DataFrame to aggregate captures by month and LandingSite
pivot_df = df_filtered.pivot_table(index='month', columns='LandingSite', aggfunc='size', fill_value=0)

# Normalize the values to get proportions
normalized_df = pivot_df.div(pivot_df.sum(axis=1), axis=0)

# Create the stacked bar plot
plt.figure(figsize=(10, 6))  # Set the figure size
normalized_df.plot(kind='bar', stacked=True, cmap='viridis')  # Create the stacked bar plot
plt.title('Proportional Contribution of LandingSites to Captures by Month (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Proportion of Captures')  # Set the label for the y-axis
plt.legend(title='LandingSite')  # Add legend with LandingSite labels
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()  # Show the plot

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Pivot the DataFrame to aggregate captures by month and LandingSite
pivot_df = df_filtered.pivot_table(index='month', columns='LandingSite', aggfunc='size', fill_value=0)

# Calculate the total captures by month
total_captures_by_month = pivot_df.sum(axis=1)

# Create the stacked bar plot
plt.figure(figsize=(12, 6))  # Set the figure size
for landing_site in pivot_df.columns:
    plt.bar(pivot_df.index, pivot_df[landing_site], label=landing_site)

plt.title('Total Captures by Month (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.legend(title='LandingSite')  # Add legend with LandingSite labels
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()  # Show the plot

# %%
# Filter the DataFrame to include only captures from 2011 or later
df_filtered = df[df['year'] >= 2011]

# Pivot the DataFrame to aggregate captures by month and LandingSite
pivot_df = df_filtered.pivot_table(index='month', columns='LandingSite', aggfunc='size', fill_value=0)

# Create the grouped bar plot
plt.figure(figsize=(12, 6))  # Set the figure size
pivot_df.plot(kind='bar', stacked=False, cmap='viridis')  # Create the grouped bar plot
plt.title('Total Captures by Month and Landing Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.legend(title='LandingSite', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add legend with LandingSite labels
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
# Pivot the DataFrame to aggregate captures by month and LandingSite
pivot_df = df_filtered.pivot_table(index='month', columns='LandingSite', aggfunc='size', fill_value=0)

# Create the stacked area plot
plt.figure(figsize=(12, 6))  # Set the figure size
pivot_df.plot(kind='area', stacked=True, cmap='viridis')  # Create the stacked area plot
plt.title('Total Captures by Month and Landing Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.legend(title='LandingSite', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add legend with LandingSite labels
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
plt.figure(figsize=(12, 6))  # Set the figure size
for landing_site in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[landing_site], label=landing_site)
plt.title('Total Captures by Month and Landing Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Month')  # Set the label for the x-axis
plt.ylabel('Number of Captures')  # Set the label for the y-axis
plt.legend(title='LandingSite', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add legend with LandingSite labels
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
sns.set(style='whitegrid')
g = sns.catplot(x='month', hue='LandingSite', data=df_filtered, kind='count', height=6, aspect=2)
g.despine(left=True)
g.set_axis_labels('Month', 'Number of Captures')
g.set_titles('Total Captures by Month and Landing Site (2011 or Later)')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(15, 8))

# Define a list of colors for each LandingSite
landing_site_colors = {
    'CaptureSiteCategory_0': 'tab:blue',
    'CaptureSiteCategory_1': 'tab:orange',
    'CaptureSiteCategory_2': 'tab:green',
    'CaptureSiteCategory_3': 'tab:red',
    'CaptureSiteCategory_4': 'tab:purple'
}

# Iterate over each month
for month in captures_by_month_site['month'].unique():
    # Filter the data for the current month
    month_data = captures_by_month_site[captures_by_month_site['month'] == month]
    
    # Plot the pie chart
    plt.subplot(3, 4, month)
    plt.pie(month_data['Number of Captures'], labels=None, autopct='%1.1f%%', startangle=140, colors=[landing_site_colors[site] for site in month_data['LandingSite']])
    plt.title(f'Distribution of Captures for Month {month}')

# Create legend
handles = [plt.Rectangle((0,0),1,1, color=color) for color in landing_site_colors.values()]
plt.legend(handles, landing_site_colors.keys(), loc='upper right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 14
#       5 landing_site_colors = {
#       6     'CaptureSiteCategory_0': 'tab:blue',
#       7     'CaptureSiteCategory_1': 'tab:orange',
#    (...)
#      10     'CaptureSiteCategory_4': 'tab:purple'
#      11 }
#      13 # Iterate over each month
# ---> 14 for month in captures_by_month_site['month'].unique():
#      15     # Filter the data for the current month
#      16     month_data = captures_by_month_site[captures_by_month_site['month'] == month]
#      18     # Plot the pie chart
#
# NameError: name 'captures_by_month_site' is not defined

# %%
# Filter the DataFrame to include captures from 2011 to 2018
df_filtered_years = df[(df['year'] >= 2011) & (df['year'] <= 2018)]

# Group the data by year and month, and calculate the total captures
captures_by_year_month = df_filtered_years.groupby(['year', 'month']).size().reset_index(name='Number of Captures')

# Set the figure size
plt.figure(figsize=(15, 8))

# Create the bar plot
sns.barplot(data=captures_by_year_month, x='year', y='Number of Captures', hue='month', palette='viridis')

# Add title and labels
plt.title('Total Number of Captures by Month (2011-2018)')
plt.xlabel('Year')
plt.ylabel('Total Number of Captures')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the DataFrame to include captures from 2011 to 2018
df_filtered_years = df[(df['year'] >= 2011) & (df['year'] <= 2018)]
grouped = df_filtered_years.groupby('LandingSite')

# Plotting
for name, group in grouped:

    # Group the data by year and month, and calculate the total captures
    captures_by_year_month = group.groupby(['year', 'month']).size().reset_index(name='Number of Captures')

    # Set the figure size
    plt.figure(figsize=(15, 8))

    # Create the bar plot
    sns.barplot(data=captures_by_year_month, x='year', y='Number of Captures', hue='month', palette='viridis')

    # Add title and labels
    plt.title('Total Number of Captures by Month (2011-2018)')
    plt.xlabel('Year')
    plt.ylabel('Total Number of Captures')
    plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=0)
    plt.tight_layout()

    # Show the plot
    plt.show()

# %%
# Filter the DataFrame to include captures from 2011 to 2018
df_filtered_years = df[(df['year'] >= 2000) & (df['year'] <= 2018)]

# Group the data by year and month, and calculate the total captures
captures_by_year_month = df_filtered_years.groupby(['year', 'month']).size().reset_index(name='Number of Captures')

# Set the figure size
plt.figure(figsize=(15, 8))

# Create the bar plot
sns.barplot(data=captures_by_year_month, x='year', y='Number of Captures', hue='month', palette='viridis')

# Add title and labels
plt.title('Total Number of Captures by Month (2011-2018)')
plt.xlabel('Year')
plt.ylabel('Total Number of Captures')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the count plot
plt.figure(figsize=(10, 6))  # Set the figure size
sns.countplot(x='LandingSite', data=status_nan, palette='viridis')  # Create the count plot
plt.title('NaN Statuses by Site (2011 or Later)')  # Set the title of the plot
plt.xlabel('Landing Site')  # Set the label for the x-axis
plt.ylabel('Number of NaN Status')  # Set the label for the y-axis
# Out:
# Text(0, 0.5, 'Number of NaN Status')

# %%
df['actual_number']
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  diff_2011  diff_2014  diff_2015
# 0                   14                 12         -6         -5         -3
# 1                    4                  4         -2         -1         -1
# 2                   10                 11          3          2          1
# 3                    0                  0         -1          0          0
# 4                    2                  1         -1          1          2
# ..                 ...                ...        ...        ...        ...
# 260                  3                  3         -3         -3         -3
# 261                  2                  2         -2         -2         -2
# 262                  4                  4         -4         -4         -4
# 263                  0                  0          0          0          0
# 264                  1                  1         -1         -1         -1
#
# [265 rows x 9 columns]

# %% [markdown]
# ## it is fair to say that during the warmer/late spring early summer months (October to January) more turtles are caught during this breeding season

# %% [markdown]
# ### There also seems to be a fairly consistent distribution among the landing sites for where employees ought to be ready to meet fishers

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# Here, the baseline model should simply be the prediction for each week at each LandingSite or CaptureSite (that part still not totally clear), based on averages of each week and site over the last however-many years we decide.
#
# It seems pretty clear to me that 2011 was when the program really started to gain some steam, in years prior, it seems like cooperation with the fishers in the area was still being fostered, and not fully developed yet. In the late 90s/early 00s, there aren't many reported captures.

# %% [markdown]
# Split the data -- (not sure how exactly yet to handle that, we need to chat about the 2019 data in the "sample sub")
#
# Calculate Average Captures: Calculate the average number of turtle captures for each combination of site and year/week of year. This involves grouping the data by site and year/week and calculating the mean number of captures for each week by year and group.
#
# Baseline Prediction: For a given site and date combination in the test data, predict the average number of captures calculated in step 2 as the baseline prediction.
#
# Evaluation: Evaluate the performance of the baseline model using appropriate metrics such as Mean Absolute Error (MAE) or Root Mean Squared Error (RMSE) by comparing the baseline predictions to the actual number of turtle captures in the test data.
#
# Interpretation: Analyze the performance of the baseline model to establish a benchmark for comparison with more advanced predictive models. This will help assess whether more sophisticated techniques offer significant improvements over the baseline, or if this is the best that can be done with the data on hand.

# %% [markdown]
# ## Morning Recap
#
# #### Consensus
#
# 1. Splitting the data -- From 2011 onward, 2018 will be our test data
# 2. ignore the submission sample
# 3. using LandingSite instead of CaptureSite (capture site category)
# 4. Week 53, leave it as it is
# 5. January dates are fine in 53
#
#
# #### To-Do
# 1. Baseline Model
# 2. Test/Evaluate Baseline Model
# 3. Machine Learning Models to compare ***
# 4. Final Product brainstorming for presentation ***
#
# *** means it is easily split between three people

# %%
df_train = df[(df['year'] <= 2017) & (df['year'] >= 2011)]
df_train
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 33         2011-06-17  CaptureSite_0          ocean  Fisher_2133  \
# 34         2011-06-22  CaptureSite_0          ocean   Fisher_513
# 35         2011-08-16  CaptureSite_0          ocean   Fisher_649
# 36         2011-08-28  CaptureSite_0          ocean   Fisher_296
# 37         2011-10-22  CaptureSite_0          ocean  Fisher_1550
# ...               ...            ...            ...          ...
# 17784      2017-12-28  CaptureSite_9          ocean  Fisher_1551
# 17785      2017-12-29  CaptureSite_9          ocean  Fisher_1343
# 17786      2017-12-30  CaptureSite_9          ocean  Fisher_1551
# 17787      2017-12-30  CaptureSite_9          ocean  Fisher_1472
# 17788      2017-12-31  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 33     CaptureSiteCategory_2   8.500000       NaN    17.0150  Type_1  2011  \
# 34     CaptureSiteCategory_2  70.000000       NaN    83.2194  Type_1  2011
# 35     CaptureSiteCategory_2   8.500000       NaN    16.1850  Type_1  2011
# 36     CaptureSiteCategory_2   6.500000  Released    13.0652  Type_1  2011
# 37     CaptureSiteCategory_2  55.708539  Released    57.7430  Type_1  2011
# ...                      ...        ...       ...        ...     ...   ...
# 17784  CaptureSiteCategory_1   6.810000  Released    13.5168  Type_1  2017
# 17785  CaptureSiteCategory_1   5.930000  Released    14.2803  Type_1  2017
# 17786  CaptureSiteCategory_1  16.500000  Released    24.4625  Type_1  2017
# 17787  CaptureSiteCategory_1  22.700000  Released    35.4200  Type_1  2017
# 17788  CaptureSiteCategory_1  11.200000  Released    18.9980  Type_1  2017
#
#        month  week_of_year  year_woy
# 33         6            24    201124
# 34         6            25    201125
# 35         8            33    201133
# 36         8            34    201134
# 37        10            42    201142
# ...      ...           ...       ...
# 17784     12            52    201752
# 17785     12            52    201752
# 17786     12            52    201752
# 17787     12            52    201752
# 17788     12            52    201752
#
# [10547 rows x 13 columns]

# %%
df_train2 = df[(df['year'] <= 2017) & (df['year'] >= 2014)]
df_train2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[353], line 1
# ----> 1 df_train2 = df[(df['year'] <= 2018) & (df['year'] >= 2014)]
#       2 df_train2
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
df_train3 = df_train2[(df_train2['year'] <= 2017) & (df_train2['year'] >= 2015)]
df_train3
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 54         2015-01-06  CaptureSite_0          ocean  Fisher_2092  \
# 55         2015-01-16  CaptureSite_0          ocean    Fisher_85
# 56         2015-03-02  CaptureSite_0          ocean  Fisher_1108
# 57         2015-04-20  CaptureSite_0          ocean  Fisher_1964
# 58         2015-04-20  CaptureSite_0          ocean  Fisher_1964
# ...               ...            ...            ...          ...
# 17784      2017-12-28  CaptureSite_9          ocean  Fisher_1551
# 17785      2017-12-29  CaptureSite_9          ocean  Fisher_1343
# 17786      2017-12-30  CaptureSite_9          ocean  Fisher_1551
# 17787      2017-12-30  CaptureSite_9          ocean  Fisher_1472
# 17788      2017-12-31  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 54     CaptureSiteCategory_2       5.00  Released    11.5500  Type_1  2015  \
# 55     CaptureSiteCategory_2       8.20  Admitted    18.0400  Type_1  2015
# 56     CaptureSiteCategory_2      27.20  Released    32.7484  Type_1  2015
# 57     CaptureSiteCategory_2      11.13  Released    19.8660  Type_1  2015
# 58     CaptureSiteCategory_2      12.53  Released    20.9216  Type_1  2015
# ...                      ...        ...       ...        ...     ...   ...
# 17784  CaptureSiteCategory_1       6.81  Released    13.5168  Type_1  2017
# 17785  CaptureSiteCategory_1       5.93  Released    14.2803  Type_1  2017
# 17786  CaptureSiteCategory_1      16.50  Released    24.4625  Type_1  2017
# 17787  CaptureSiteCategory_1      22.70  Released    35.4200  Type_1  2017
# 17788  CaptureSiteCategory_1      11.20  Released    18.9980  Type_1  2017
#
#        month  week_of_year  year_woy
# 54         1             2    201502
# 55         1             3    201503
# 56         3            10    201510
# 57         4            17    201517
# 58         4            17    201517
# ...      ...           ...       ...
# 17784     12            52    201752
# 17785     12            52    201752
# 17786     12            52    201752
# 17787     12            52    201752
# 17788     12            52    201752
#
# [4540 rows x 13 columns]

# %%
df_last2y = df_train2[(df_train2['year'] <= 2017) & (df_train2['year'] >= 2016)]
df_last2y
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 72         2016-02-17  CaptureSite_0          ocean   Fisher_649  \
# 73         2016-03-23  CaptureSite_0          ocean  Fisher_1964
# 74         2016-03-23  CaptureSite_0          ocean  Fisher_1964
# 75         2016-05-12  CaptureSite_0          ocean    Fisher_44
# 76         2016-06-06  CaptureSite_0          ocean  Fisher_1964
# ...               ...            ...            ...          ...
# 17784      2017-12-28  CaptureSite_9          ocean  Fisher_1551
# 17785      2017-12-29  CaptureSite_9          ocean  Fisher_1343
# 17786      2017-12-30  CaptureSite_9          ocean  Fisher_1551
# 17787      2017-12-30  CaptureSite_9          ocean  Fisher_1472
# 17788      2017-12-31  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 72     CaptureSiteCategory_2       7.81  Released    15.6800  Type_1  2016  \
# 73     CaptureSiteCategory_2       8.63  Released    16.5200  Type_1  2016
# 74     CaptureSiteCategory_2      10.87  Released    19.2621  Type_1  2016
# 75     CaptureSiteCategory_2      93.60  Released    90.7768  Type_1  2016
# 76     CaptureSiteCategory_2       8.14  Released    17.0872  Type_1  2016
# ...                      ...        ...       ...        ...     ...   ...
# 17784  CaptureSiteCategory_1       6.81  Released    13.5168  Type_1  2017
# 17785  CaptureSiteCategory_1       5.93  Released    14.2803  Type_1  2017
# 17786  CaptureSiteCategory_1      16.50  Released    24.4625  Type_1  2017
# 17787  CaptureSiteCategory_1      22.70  Released    35.4200  Type_1  2017
# 17788  CaptureSiteCategory_1      11.20  Released    18.9980  Type_1  2017
#
#        month  week_of_year  year_woy
# 72         2             7    201607
# 73         3            12    201612
# 74         3            12    201612
# 75         5            19    201619
# 76         6            23    201623
# ...      ...           ...       ...
# 17784     12            52    201752
# 17785     12            52    201752
# 17786     12            52    201752
# 17787     12            52    201752
# 17788     12            52    201752
#
# [2950 rows x 13 columns]

# %%
# do not run this without resetting the kernal!! df is used later!!
df_test = df[df['year'] == 2018]
df_test[df_test['LandingSite'] == 'CaptureSiteCategory_3']
df_test
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 85         2018-01-14  CaptureSite_0          ocean   Fisher_809  \
# 86         2018-01-17  CaptureSite_0          ocean   Fisher_809
# 87         2018-02-01  CaptureSite_0          ocean   Fisher_809
# 88         2018-02-19  CaptureSite_0          ocean   Fisher_809
# 89         2018-06-21  CaptureSite_0          ocean   Fisher_606
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 85     CaptureSiteCategory_2   4.250000  Released  10.889100  Type_1  2018  \
# 86     CaptureSiteCategory_2   2.680000  Released   7.600760  Type_1  2018
# 87     CaptureSiteCategory_2   5.450000  Released  12.320930  Type_1  2018
# 88     CaptureSiteCategory_2   3.440000  Released   9.017439  Type_1  2018
# 89     CaptureSiteCategory_2  10.410000  Released  18.870561  Type_1  2018
# ...                      ...        ...       ...        ...     ...   ...
# 18057  CaptureSiteCategory_1  21.090000  Released  28.890641  Type_1  2018
# 18058  CaptureSiteCategory_1   9.020000  Released  16.142259  Type_1  2018
# 18059  CaptureSiteCategory_1  20.461698  Released  29.915600  Type_1  2018
# 18060  CaptureSiteCategory_1  15.618496  Released  25.171500  Type_1  2018
# 18061  CaptureSiteCategory_1   4.290000  Released  10.795200  Type_1  2018
#
#        month  week_of_year  year_woy
# 85         1             2    201802
# 86         1             3    201803
# 87         2             5    201805
# 88         2             8    201808
# 89         6            25    201825
# ...      ...           ...       ...
# 18057     12            51    201851
# 18058     12            51    201851
# 18059     12            52    201852
# 18060     12            52    201852
# 18061     12            52    201852
#
# [1561 rows x 13 columns]

# %%
def get_month_for_week(year, week_number):
    mid_week_date = datetime.datetime.strptime(f'{year}-W{week_number}-4', "%Y-W%W-%w").date()
    return mid_week_date.month

# Apply the function to each row in the DataFrame to create the 'month_round' column
df_test['month_round'] = df_test.apply(lambda row: get_month_for_week(row['year'], row['week_of_year']), axis=1)

# Display the DataFrame with the new 'month_round' column
df_test
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 85         2018-01-14  CaptureSite_0          ocean   Fisher_809  \
# 86         2018-01-17  CaptureSite_0          ocean   Fisher_809
# 87         2018-02-01  CaptureSite_0          ocean   Fisher_809
# 88         2018-02-19  CaptureSite_0          ocean   Fisher_809
# 89         2018-06-21  CaptureSite_0          ocean   Fisher_606
# ...               ...            ...            ...          ...
# 18057      2018-12-18  CaptureSite_9          ocean   Fisher_569
# 18058      2018-12-18  CaptureSite_9          ocean   Fisher_125
# 18059      2018-12-24  CaptureSite_9          ocean  Fisher_1343
# 18060      2018-12-24  CaptureSite_9          ocean  Fisher_1551
# 18061      2018-12-28  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 85     CaptureSiteCategory_2   4.250000  Released  10.889100  Type_1  2018  \
# 86     CaptureSiteCategory_2   2.680000  Released   7.600760  Type_1  2018
# 87     CaptureSiteCategory_2   5.450000  Released  12.320930  Type_1  2018
# 88     CaptureSiteCategory_2   3.440000  Released   9.017439  Type_1  2018
# 89     CaptureSiteCategory_2  10.410000  Released  18.870561  Type_1  2018
# ...                      ...        ...       ...        ...     ...   ...
# 18057  CaptureSiteCategory_1  21.090000  Released  28.890641  Type_1  2018
# 18058  CaptureSiteCategory_1   9.020000  Released  16.142259  Type_1  2018
# 18059  CaptureSiteCategory_1  20.461698  Released  29.915600  Type_1  2018
# 18060  CaptureSiteCategory_1  15.618496  Released  25.171500  Type_1  2018
# 18061  CaptureSiteCategory_1   4.290000  Released  10.795200  Type_1  2018
#
#        month  week_of_year  year_woy  month_round
# 85         1             2    201802            1
# 86         1             3    201803            1
# 87         2             5    201805            2
# 88         2             8    201808            2
# 89         6            25    201825            6
# ...      ...           ...       ...          ...
# 18057     12            51    201851           12
# 18058     12            51    201851           12
# 18059     12            52    201852           12
# 18060     12            52    201852           12
# 18061     12            52    201852           12
#
# [1561 rows x 14 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_week_train = df_train.groupby(['LandingSite', 'year', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_week_train
# Out:
#                 LandingSite  year  week_of_year  year_woy  number_turtles
# 0     CaptureSiteCategory_0  2011             1    201101              21
# 1     CaptureSiteCategory_0  2011             2    201102              12
# 2     CaptureSiteCategory_0  2011             3    201103               2
# 3     CaptureSiteCategory_0  2011             4    201104               6
# 4     CaptureSiteCategory_0  2011             5    201105               5
# ...                     ...   ...           ...       ...             ...
# 1451  CaptureSiteCategory_4  2017            48    201748               8
# 1452  CaptureSiteCategory_4  2017            49    201749               5
# 1453  CaptureSiteCategory_4  2017            50    201750              12
# 1454  CaptureSiteCategory_4  2017            51    201751               1
# 1455  CaptureSiteCategory_4  2017            52    201752               6
#
# [1456 rows x 5 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_week_train2 = df_train2.groupby(['LandingSite', 'year', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_week_train2
# Out:
#                LandingSite  year  week_of_year  year_woy  number_turtles
# 0    CaptureSiteCategory_0  2014             1    201401              17
# 1    CaptureSiteCategory_0  2014             2    201402              39
# 2    CaptureSiteCategory_0  2014             3    201403               3
# 3    CaptureSiteCategory_0  2014             4    201404              14
# 4    CaptureSiteCategory_0  2014             5    201405               8
# ..                     ...   ...           ...       ...             ...
# 834  CaptureSiteCategory_4  2017            48    201748               8
# 835  CaptureSiteCategory_4  2017            49    201749               5
# 836  CaptureSiteCategory_4  2017            50    201750              12
# 837  CaptureSiteCategory_4  2017            51    201751               1
# 838  CaptureSiteCategory_4  2017            52    201752               6
#
# [839 rows x 5 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_month_train2 = df_train2.groupby(['LandingSite', 'year', 'month', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_month_train2
# Out:
#                LandingSite  year  month  week_of_year  year_woy
# 0    CaptureSiteCategory_0  2014      1             1    201401  \
# 1    CaptureSiteCategory_0  2014      1             2    201402
# 2    CaptureSiteCategory_0  2014      1             3    201403
# 3    CaptureSiteCategory_0  2014      1             4    201404
# 4    CaptureSiteCategory_0  2014      1             5    201405
# ..                     ...   ...    ...           ...       ...
# 932  CaptureSiteCategory_4  2017     12            48    201748
# 933  CaptureSiteCategory_4  2017     12            49    201749
# 934  CaptureSiteCategory_4  2017     12            50    201750
# 935  CaptureSiteCategory_4  2017     12            51    201751
# 936  CaptureSiteCategory_4  2017     12            52    201752
#
#      number_turtles
# 0                 1
# 1                39
# 2                 3
# 3                14
# 4                 7
# ..              ...
# 932               3
# 933               5
# 934              12
# 935               1
# 936               6
#
# [937 rows x 6 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_week_train3 = df_train3.groupby(['LandingSite', 'year', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_week_train3
# Out:
#                LandingSite  year  week_of_year  year_woy  number_turtles
# 0    CaptureSiteCategory_0  2015             1    201501               9
# 1    CaptureSiteCategory_0  2015             2    201502              11
# 2    CaptureSiteCategory_0  2015             3    201503              25
# 3    CaptureSiteCategory_0  2015             4    201504               1
# 4    CaptureSiteCategory_0  2015             5    201505              19
# ..                     ...   ...           ...       ...             ...
# 625  CaptureSiteCategory_4  2017            48    201748               8
# 626  CaptureSiteCategory_4  2017            49    201749               5
# 627  CaptureSiteCategory_4  2017            50    201750              12
# 628  CaptureSiteCategory_4  2017            51    201751               1
# 629  CaptureSiteCategory_4  2017            52    201752               6
#
# [630 rows x 5 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_week_last2y = df_last2y.groupby(['LandingSite', 'year', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_week_last2y
# Out:
#                LandingSite  year  week_of_year  year_woy  number_turtles
# 0    CaptureSiteCategory_0  2016             1    201601              10
# 1    CaptureSiteCategory_0  2016             2    201602               6
# 2    CaptureSiteCategory_0  2016             3    201603              13
# 3    CaptureSiteCategory_0  2016             4    201604               4
# 4    CaptureSiteCategory_0  2016             5    201605              17
# ..                     ...   ...           ...       ...             ...
# 405  CaptureSiteCategory_4  2017            48    201748               8
# 406  CaptureSiteCategory_4  2017            49    201749               5
# 407  CaptureSiteCategory_4  2017            50    201750              12
# 408  CaptureSiteCategory_4  2017            51    201751               1
# 409  CaptureSiteCategory_4  2017            52    201752               6
#
# [410 rows x 5 columns]

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_week_test = df_test.groupby(['LandingSite', 'year', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_week_test[turtle_week_test['LandingSite'] == 'CaptureSiteCategory_3']
# Out:
#                LandingSite  year  week_of_year  year_woy  number_turtles
# 154  CaptureSiteCategory_3  2018             5    201805               1
# 155  CaptureSiteCategory_3  2018            18    201818               1
# 156  CaptureSiteCategory_3  2018            33    201833               1
# 157  CaptureSiteCategory_3  2018            37    201837               1
# 158  CaptureSiteCategory_3  2018            39    201839               1
# 159  CaptureSiteCategory_3  2018            45    201845               1

# %% [markdown]
# ## somewhere above i made a function that rounds the month assignment to week of year based on which month has more days in that particular week, to deal with cusping weeks and eliminating duplicates

# %%
# Group by 'LandingSite', 'year', and 'week_of_year', then count the number of turtle captures
turtle_month_test = df_test.groupby(['LandingSite', 'year', 'month_round', 'week_of_year', 'year_woy']).size().reset_index(name='number_turtles')

# Display the result
turtle_month_test
# Out:
#                LandingSite  year  month_round  week_of_year  year_woy
# 0    CaptureSiteCategory_0  2018            1             1    201801  \
# 1    CaptureSiteCategory_0  2018            1             2    201802
# 2    CaptureSiteCategory_0  2018            1             3    201803
# 3    CaptureSiteCategory_0  2018            1             4    201804
# 4    CaptureSiteCategory_0  2018            2             5    201805
# ..                     ...   ...          ...           ...       ...
# 205  CaptureSiteCategory_4  2018           11            48    201848
# 206  CaptureSiteCategory_4  2018           12            49    201849
# 207  CaptureSiteCategory_4  2018           12            50    201850
# 208  CaptureSiteCategory_4  2018           12            51    201851
# 209  CaptureSiteCategory_4  2018           12            52    201852
#
#      number_turtles
# 0                 9
# 1                13
# 2                 5
# 3                 7
# 4                 9
# ..              ...
# 205              10
# 206               3
# 207               6
# 208               2
# 209               5
#
# [210 rows x 6 columns]

# %%
all_sites_m = turtle_month_test['LandingSite'].unique()
all_weeks_m = range(1, 54)  # 53 weeks in a year
# all_years_m = turtle_month_test['year'].unique()  # assuming data is only for one year (2018)

# Create a DataFrame with all possible combinations
template_df = pd.DataFrame([(site, week) for site in all_sites_m 
                                            #   for year in all_years_m 
                                         for week in all_weeks_m],
                           columns=['LandingSite', 'week_of_year'])

# Merge the template DataFrame with turtle_month_test DataFrame to fill in missing values
month_round = pd.merge(template_df, turtle_month_test, on=['LandingSite', 'week_of_year'], how='left')

# Fill missing values with 0 for number_turtles column
month_round['number_turtles'].fillna(0, inplace=True)

# Calculate the month_round column using the function we defined earlier
month_round['month_round'] = month_round.apply(lambda row: get_month_for_week(2018, row['week_of_year']), axis=1)

# Reorder columns if needed
month_round_test = month_round[['LandingSite', 'week_of_year', 'month_round', 'number_turtles']]

# Display the resulting DataFrame
month_round_test
# Out:
#                LandingSite  month_round  week_of_year  number_turtles
# 0    CaptureSiteCategory_0            1             1             9.0
# 1    CaptureSiteCategory_0            1             2            13.0
# 2    CaptureSiteCategory_0            1             3             5.0
# 3    CaptureSiteCategory_0            1             4             7.0
# 4    CaptureSiteCategory_0            2             5             9.0
# ..                     ...          ...           ...             ...
# 260  CaptureSiteCategory_4           12            49             3.0
# 261  CaptureSiteCategory_4           12            50             6.0
# 262  CaptureSiteCategory_4           12            51             2.0
# 263  CaptureSiteCategory_4           12            52             5.0
# 264  CaptureSiteCategory_4            1            53             0.0
#
# [265 rows x 4 columns]

# %% [markdown]
# ### getting the means of each week by year by landing site

# %%
train_mean = turtle_week_train.groupby(['LandingSite', 'week_of_year'])['number_turtles'].mean().reset_index(name='mean_turtles')
train_mean['mean_turtles'] = train_mean['mean_turtles'].round()
train_mean
# Out:
#                LandingSite  week_of_year  mean_turtles
# 0    CaptureSiteCategory_0             1          15.0
# 1    CaptureSiteCategory_0             2          18.0
# 2    CaptureSiteCategory_0             3          12.0
# 3    CaptureSiteCategory_0             4          11.0
# 4    CaptureSiteCategory_0             5          18.0
# ..                     ...           ...           ...
# 236  CaptureSiteCategory_4            49           6.0
# 237  CaptureSiteCategory_4            50           7.0
# 238  CaptureSiteCategory_4            51           6.0
# 239  CaptureSiteCategory_4            52           4.0
# 240  CaptureSiteCategory_4            53           1.0
#
# [241 rows x 3 columns]

# %%
train_mean2 = turtle_week_train2.groupby(['LandingSite', 'week_of_year'])['number_turtles'].mean().reset_index(name='mean_turtles')
train_mean2['mean_turtles'] = train_mean2['mean_turtles'].round()
train_mean2
# Out:
#                LandingSite  week_of_year  mean_turtles
# 0    CaptureSiteCategory_0             1          14.0
# 1    CaptureSiteCategory_0             2          16.0
# 2    CaptureSiteCategory_0             3          11.0
# 3    CaptureSiteCategory_0             4           6.0
# 4    CaptureSiteCategory_0             5          15.0
# ..                     ...           ...           ...
# 225  CaptureSiteCategory_4            49           5.0
# 226  CaptureSiteCategory_4            50           7.0
# 227  CaptureSiteCategory_4            51           3.0
# 228  CaptureSiteCategory_4            52           4.0
# 229  CaptureSiteCategory_4            53           1.0
#
# [230 rows x 3 columns]

# %%
train_mean2_month = turtle_month_train2.groupby(['LandingSite', 'month'])['number_turtles'].mean().reset_index(name='mean_turtles_month_2014')
train_mean2_month['mean_turtles'] = train_mean2_month['mean_turtles_month_2014'].round()
train_mean2_month
# Out:
#               LandingSite  month  mean_turtles_month_2014  mean_turtles
# 0   CaptureSiteCategory_0      1                 9.750000          10.0
# 1   CaptureSiteCategory_0      2                 8.650000           9.0
# 2   CaptureSiteCategory_0      3                10.300000          10.0
# 3   CaptureSiteCategory_0      4                 9.052632           9.0
# 4   CaptureSiteCategory_0      5                 7.095238           7.0
# 5   CaptureSiteCategory_0      6                 9.600000          10.0
# 6   CaptureSiteCategory_0      7                 9.809524          10.0
# 7   CaptureSiteCategory_0      8                 9.761905          10.0
# 8   CaptureSiteCategory_0      9                11.100000          11.0
# 9   CaptureSiteCategory_0     10                12.952381          13.0
# 10  CaptureSiteCategory_0     11                14.300000          14.0
# 11  CaptureSiteCategory_0     12                13.789474          14.0
# 12  CaptureSiteCategory_1      1                 4.277778           4.0
# 13  CaptureSiteCategory_1      2                 5.312500           5.0
# 14  CaptureSiteCategory_1      3                 5.000000           5.0
# 15  CaptureSiteCategory_1      4                 3.894737           4.0
# 16  CaptureSiteCategory_1      5                 4.294118           4.0
# 17  CaptureSiteCategory_1      6                 2.941176           3.0
# 18  CaptureSiteCategory_1      7                 3.888889           4.0
# 19  CaptureSiteCategory_1      8                 3.705882           4.0
# 20  CaptureSiteCategory_1      9                 4.000000           4.0
# 21  CaptureSiteCategory_1     10                 5.200000           5.0
# 22  CaptureSiteCategory_1     11                 7.222222           7.0
# 23  CaptureSiteCategory_1     12                 6.764706           7.0
# 24  CaptureSiteCategory_2      1                 7.550000           8.0
# 25  CaptureSiteCategory_2      2                 7.000000           7.0
# 26  CaptureSiteCategory_2      3                 6.428571           6.0
# 27  CaptureSiteCategory_2      4                 6.450000           6.0
# 28  CaptureSiteCategory_2      5                 6.047619           6.0
# 29  CaptureSiteCategory_2      6                 5.200000           5.0
# 30  CaptureSiteCategory_2      7                 5.555556           6.0
# 31  CaptureSiteCategory_2      8                 5.000000           5.0
# 32  CaptureSiteCategory_2      9                 6.894737           7.0
# 33  CaptureSiteCategory_2     10                 8.714286           9.0
# 34  CaptureSiteCategory_2     11                10.666667          11.0
# 35  CaptureSiteCategory_2     12                10.850000          11.0
# 36  CaptureSiteCategory_3      1                 1.000000           1.0
# 37  CaptureSiteCategory_3      2                 1.000000           1.0
# 38  CaptureSiteCategory_3      3                 1.000000           1.0
# 39  CaptureSiteCategory_3      4                 1.000000           1.0
# 40  CaptureSiteCategory_3      5                 1.000000           1.0
# 41  CaptureSiteCategory_3      6                 1.333333           1.0
# 42  CaptureSiteCategory_3      7                 1.000000           1.0
# 43  CaptureSiteCategory_3      8                 1.000000           1.0
# 44  CaptureSiteCategory_3     10                 1.000000           1.0
# 45  CaptureSiteCategory_3     11                 1.333333           1.0
# 46  CaptureSiteCategory_3     12                 1.000000           1.0
# 47  CaptureSiteCategory_4      1                 2.526316           3.0
# 48  CaptureSiteCategory_4      2                 3.562500           4.0
# 49  CaptureSiteCategory_4      3                 3.647059           4.0
# 50  CaptureSiteCategory_4      4                 3.941176           4.0
# 51  CaptureSiteCategory_4      5                 2.666667           3.0
# 52  CaptureSiteCategory_4      6                 4.947368           5.0
# 53  CaptureSiteCategory_4      7                 4.315789           4.0
# 54  CaptureSiteCategory_4      8                 3.736842           4.0
# 55  CaptureSiteCategory_4      9                 3.421053           3.0
# 56  CaptureSiteCategory_4     10                 4.631579           5.0
# 57  CaptureSiteCategory_4     11                 4.842105           5.0
# 58  CaptureSiteCategory_4     12                 4.650000           5.0

# %%
train_mean3 = turtle_week_train3.groupby(['LandingSite', 'week_of_year'])['number_turtles'].mean().reset_index(name='mean_turtles')
train_mean3['mean_turtles'] = train_mean3['mean_turtles'].round()
train_mean3
# Out:
#                LandingSite  week_of_year  mean_turtles
# 0    CaptureSiteCategory_0             1          12.0
# 1    CaptureSiteCategory_0             2           8.0
# 2    CaptureSiteCategory_0             3          14.0
# 3    CaptureSiteCategory_0             4           3.0
# 4    CaptureSiteCategory_0             5          18.0
# ..                     ...           ...           ...
# 222  CaptureSiteCategory_4            49           6.0
# 223  CaptureSiteCategory_4            50           9.0
# 224  CaptureSiteCategory_4            51           2.0
# 225  CaptureSiteCategory_4            52           4.0
# 226  CaptureSiteCategory_4            53           1.0
#
# [227 rows x 3 columns]

# %%
train_mean_last2y = turtle_week_last2y.groupby(['LandingSite', 'week_of_year'])['number_turtles'].mean().reset_index(name='mean_turtles')
train_mean_last2y['mean_turtles'] = train_mean_last2y['mean_turtles'].round()
train_mean_last2y
# Out:
#                LandingSite  week_of_year  mean_turtles
# 0    CaptureSiteCategory_0             1          14.0
# 1    CaptureSiteCategory_0             2           6.0
# 2    CaptureSiteCategory_0             3           8.0
# 3    CaptureSiteCategory_0             4           4.0
# 4    CaptureSiteCategory_0             5          17.0
# ..                     ...           ...           ...
# 213  CaptureSiteCategory_4            49           6.0
# 214  CaptureSiteCategory_4            50           9.0
# 215  CaptureSiteCategory_4            51           3.0
# 216  CaptureSiteCategory_4            52           4.0
# 217  CaptureSiteCategory_4            53           1.0
#
# [218 rows x 3 columns]

# %%
# train_mean['actual_number'] = turtle_week_test['number_turtles']
# train_mean
# Out:
#                LandingSite  week_of_year  mean_turtles  actual_number
# 0    CaptureSiteCategory_0             1          15.0            9.0
# 1    CaptureSiteCategory_0             2          18.0           13.0
# 2    CaptureSiteCategory_0             3          12.0            5.0
# 3    CaptureSiteCategory_0             4          11.0            7.0
# 4    CaptureSiteCategory_0             5          18.0            9.0
# ..                     ...           ...           ...            ...
# 236  CaptureSiteCategory_4            49           6.0            NaN
# 237  CaptureSiteCategory_4            50           7.0            NaN
# 238  CaptureSiteCategory_4            51           6.0            NaN
# 239  CaptureSiteCategory_4            52           4.0            NaN
# 240  CaptureSiteCategory_4            53           1.0            NaN
#
# [241 rows x 4 columns]

# %%
train_mean3
# Out:
#                LandingSite  week_of_year  mean_turtles
# 0    CaptureSiteCategory_0             1          12.0
# 1    CaptureSiteCategory_0             2           8.0
# 2    CaptureSiteCategory_0             3          14.0
# 3    CaptureSiteCategory_0             4           3.0
# 4    CaptureSiteCategory_0             5          18.0
# ..                     ...           ...           ...
# 222  CaptureSiteCategory_4            49           6.0
# 223  CaptureSiteCategory_4            50           9.0
# 224  CaptureSiteCategory_4            51           2.0
# 225  CaptureSiteCategory_4            52           4.0
# 226  CaptureSiteCategory_4            53           1.0
#
# [227 rows x 3 columns]

# %%
# all_months = pd.DataFrame({'month': range(1,13)})
all_weeks = pd.DataFrame({'week_of_year': range(1, 54)})
all_sites = pd.DataFrame({'LandingSite': turtle_week_train['LandingSite'].unique()})

# Cartesian product to get all possible combinations of 'week_of_year' and 'LandingSite'
all_combinations = all_weeks.assign(key=1).merge(all_sites.assign(key=1), on='key').drop(columns='key')

# Merge with the aggregated DataFrame to fill in missing values with 0
train_mean_all = all_combinations.merge(train_mean, how='left', on=['LandingSite', 'week_of_year']).fillna(0)
train_mean_all = train_mean_all.merge(train_mean2, how='left', on=['LandingSite', 'week_of_year']).fillna(0)
train_mean_all = train_mean_all.merge(train_mean3, how='left', on=['LandingSite', 'week_of_year']).fillna(0)
# train_mean_all = train_mean_all.merge(train_mean2_month, how='left', on=['LandingSite', 'month']).fillna(0)
train_mean_all = train_mean_all.merge(turtle_week_test, how='left', on=['LandingSite', 'week_of_year']).fillna(0)

train_mean_all['mean_turtles_2011'] = train_mean_all['mean_turtles_x'].round().astype(int)
train_mean_all['mean_turtles_2014'] = train_mean_all['mean_turtles_y'].round().astype(int)
train_mean_all['mean_turtles_2015'] = train_mean_all['mean_turtles'].round().astype(int)
train_mean_all['actual_number'] = train_mean_all['number_turtles'].round().astype(int)

train_mean_all.drop('mean_turtles_y', axis=1, inplace=True)
train_mean_all.drop('mean_turtles_x', axis=1, inplace=True)
train_mean_all.drop('mean_turtles', axis=1, inplace=True)
train_mean_all.drop('year', axis=1, inplace=True)
train_mean_all.drop('year_woy', axis=1, inplace=True)
train_mean_all.drop('number_turtles', axis=1, inplace=True)

train_mean_all
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015
# 0                   14                 12
# 1                    4                  4
# 2                   10                 11
# 3                    0                  0
# 4                    2                  1
# ..                 ...                ...
# 260                  3                  3
# 261                  2                  2
# 262                  4                  4
# 263                  0                  0
# 264                  1                  1
#
# [265 rows x 6 columns]

# %%
train_mean_all.drop('mean_turtles_y', axis=1, inplace=True)
train_mean_all.drop('mean_turtles_x', axis=1, inplace=True)

train_mean_all = train_mean_all.merge(train_mean_last2y, how='left', on=['LandingSite', 'week_of_year']).fillna(0)
train_mean_all['mean_turtles_last2y'] = train_mean_all['mean_turtles'].round().astype(int)
# train_mean_all.drop('mean_turtles', axis=1, inplace=True)
train_mean_all
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  mean_turtles
# 0                   14                 12                   14          14.0
# 1                    4                  4                    2           2.0
# 2                   10                 11                   16          16.0
# 3                    0                  0                    0           0.0
# 4                    2                  1                    2           2.0
# ..                 ...                ...                  ...           ...
# 260                  3                  3                    1           1.0
# 261                  2                  2                    2           2.0
# 262                  4                  4                    1           1.0
# 263                  0                  0                    0           0.0
# 264                  1                  1                    1           1.0
#
# [265 rows x 8 columns]

# %%
train_mean_all.drop('mean_turtles', axis=1, inplace=True)
train_mean_all
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y
# 0                   14                 12                   14
# 1                    4                  4                    2
# 2                   10                 11                   16
# 3                    0                  0                    0
# 4                    2                  1                    2
# ..                 ...                ...                  ...
# 260                  3                  3                    1
# 261                  2                  2                    2
# 262                  4                  4                    1
# 263                  0                  0                    0
# 264                  1                  1                    1
#
# [265 rows x 7 columns]

# %%
all_sites_m = df['LandingSite'].unique()
all_months = range(1, 13)  # 12 months in a year

# Create a DataFrame with all possible combinations
template_df = pd.DataFrame([(site, month) for site in all_sites_m 
                                           for month in all_months],
                           columns=['LandingSite', 'month'])

# Merge the template DataFrame with train_mean2_month to fill in missing values
month_full = pd.merge(template_df, train_mean2_month, on=['LandingSite', 'month'], how='left')

# Fill missing values with 0 for mean_turtles column
month_full['mean_turtles'].fillna(0, inplace=True)

month_round_test_compare = pd.merge(month_round_test, month_full[['LandingSite', 'month', 'mean_turtles']], 
                            left_on=['LandingSite', 'month_round'], right_on=['LandingSite', 'month'], how='left')

# Rename the column if needed
month_round_test_compare.rename(columns={'mean_turtles': 'mean_turtles_month'}, inplace=True)
# month_round_test_compare['mean_turtles_month'] = month_round_test_compare['mean_turtles_month'].round().astype(int)

# Sort the DataFrame first by 'week_of_year' and then by 'LandingSite'
month_round_test_compare_sorted = month_round_test_compare.sort_values(by=['week_of_year', 'LandingSite'])

# Display the sorted DataFrame
month_round_test_compare = month_round_test_compare_sorted[['week_of_year', 'LandingSite', 'month_round', 'mean_turtles_month', 'number_turtles']]
month_round_test_compare
# Out:
#      week_of_year            LandingSite  month_round  mean_turtles_month
# 0               1  CaptureSiteCategory_0            1                10.0  \
# 53              1  CaptureSiteCategory_1            1                 4.0
# 106             1  CaptureSiteCategory_2            1                 8.0
# 159             1  CaptureSiteCategory_3            1                 1.0
# 212             1  CaptureSiteCategory_4            1                 3.0
# ..            ...                    ...          ...                 ...
# 52             53  CaptureSiteCategory_0            1                10.0
# 105            53  CaptureSiteCategory_1            1                 4.0
# 158            53  CaptureSiteCategory_2            1                 8.0
# 211            53  CaptureSiteCategory_3            1                 1.0
# 264            53  CaptureSiteCategory_4            1                 3.0
#
#      number_turtles
# 0               9.0
# 53              3.0
# 106            12.0
# 159             0.0
# 212             3.0
# ..              ...
# 52              0.0
# 105             0.0
# 158             0.0
# 211             0.0
# 264             0.0
#
# [265 rows x 5 columns]

# %%
train_mean_all['diff_2011'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_2011']
train_mean_all['diff_2014'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_2014']
train_mean_all['diff_2015'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_2015']
train_mean_all['diff_last2y'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_last2y']

# train_mean_all['mean_turtles_month'] = month_round_test_compare['mean_turtles_month']
# train_mean_all['diff_month'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_month']

# Merge the two DataFrames based on 'week_of_year' and 'LandingSite'
train_mean_all = pd.merge(train_mean_all, month_round_test_compare[['week_of_year', 'LandingSite', 'mean_turtles_month']], 
                         on=['week_of_year', 'LandingSite'], how='left')

# Drop the duplicate column
# train_mean_all.drop(columns=['diff_month'], inplace=True)

train_mean_all['diff_month'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_month']

# Display the resulting DataFrame
train_mean_all

df = train_mean_all
df.tail(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean_turtles_month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[354], line 16
#      10 train_mean_all = pd.merge(train_mean_all, month_round_test_compare[['week_of_year', 'LandingSite', 'mean_turtles_month']],
#      11                          on=['week_of_year', 'LandingSite'], how='left')
#      13 # Drop the duplicate column
#      14 # train_mean_all.drop(columns=['diff_month'], inplace=True)
# ---> 16 train_mean_all['diff_month'] = train_mean_all['actual_number'] - train_mean_all['mean_turtles_month']
#      18 # Display the resulting DataFrame
#      19 train_mean_all
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/repos/turtles/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'mean_turtles_month'

# %%
df.tail(20)
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 245            50  CaptureSiteCategory_0             24                 15  \
# 246            50  CaptureSiteCategory_1             12                  9
# 247            50  CaptureSiteCategory_2             21                 11
# 248            50  CaptureSiteCategory_3              0                  1
# 249            50  CaptureSiteCategory_4              6                  7
# 250            51  CaptureSiteCategory_0             16                 14
# 251            51  CaptureSiteCategory_1              5                  8
# 252            51  CaptureSiteCategory_2              5                 12
# 253            51  CaptureSiteCategory_3              0                  0
# 254            51  CaptureSiteCategory_4              2                  6
# 255            52  CaptureSiteCategory_0             14                 11
# 256            52  CaptureSiteCategory_1              3                  6
# 257            52  CaptureSiteCategory_2              4                  6
# 258            52  CaptureSiteCategory_3              0                  0
# 259            52  CaptureSiteCategory_4              5                  4
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  diff_2011
# 245                 14                 11                   10          9  \
# 246                  8                  7                    8          3
# 247                 14                 14                   12         10
# 248                  1                  1                    1         -1
# 249                  7                  9                    9         -1
# 250                 14                 14                   10          2
# 251                  9                  8                    8         -3
# 252                 17                 21                   18         -7
# 253                  0                  0                    0          0
# 254                  3                  2                    3         -4
# 255                 12                 10                    8          3
# 256                  6                  6                    7         -3
# 257                  8                  8                    8         -2
# 258                  0                  0                    0          0
# 259                  4                  4                    4          1
# 260                  3                  3                    1         -3
# 261                  2                  2                    2         -2
# 262                  4                  4                    1         -4
# 263                  0                  0                    0          0
# 264                  1                  1                    1         -1
#
#      diff_2014  diff_2015  diff_last2y  mean_turtles_month  diff_month
# 245         10         13           14                14.0        10.0  \
# 246          4          5            4                 7.0         5.0
# 247          7          7            9                11.0        10.0
# 248         -1         -1           -1                 1.0        -1.0
# 249         -1         -3           -3                 5.0         1.0
# 250          2          2            6                14.0         2.0
# 251         -4         -3           -3                 7.0        -2.0
# 252        -12        -16          -13                11.0        -6.0
# 253          0          0            0                 1.0        -1.0
# 254         -1          0           -1                 5.0        -3.0
# 255          2          4            6                14.0         0.0
# 256         -3         -3           -4                 7.0        -4.0
# 257         -4         -4           -4                11.0        -7.0
# 258          0          0            0                 1.0        -1.0
# 259          1          1            1                 5.0         0.0
# 260         -3         -3           -1                10.0       -10.0
# 261         -2         -2           -2                 4.0        -4.0
# 262         -4         -4           -1                 8.0        -8.0
# 263          0          0            0                 1.0        -1.0
# 264         -1         -1           -1                 3.0        -3.0
#
#      mean_turtles_month_2014  diff_month_2014  mean_turtles_month_2014_last2y
# 245                     14.0             10.0                            14.0  \
# 246                      8.0              4.0                             8.0
# 247                     12.0              9.0                            12.0
# 248                      1.0             -1.0                             1.0
# 249                      6.0              0.0                             6.0
# 250                     14.0              2.0                            14.0
# 251                      8.0             -3.0                             8.0
# 252                     14.0             -9.0                            14.0
# 253                      0.0              0.0                             0.0
# 254                      4.0             -2.0                             4.0
# 255                     13.0              1.0                            12.0
# 256                      6.0             -3.0                             6.0
# 257                     10.0             -6.0                            10.0
# 258                      0.0              0.0                             0.0
# 259                      4.0              1.0                             4.0
# 260                      6.0             -6.0                             6.0
# 261                      3.0             -3.0                             3.0
# 262                      6.0             -6.0                             6.0
# 263                      0.0              0.0                             0.0
# 264                      2.0             -2.0                             2.0
#
#      diff_month_2014_last2y
# 245                    10.0
# 246                     4.0
# 247                     9.0
# 248                    -1.0
# 249                     0.0
# 250                     2.0
# 251                    -3.0
# 252                    -9.0
# 253                     0.0
# 254                    -2.0
# 255                     2.0
# 256                    -3.0
# 257                    -6.0
# 258                     0.0
# 259                     1.0
# 260                    -6.0
# 261                    -3.0
# 262                    -6.0
# 263                     0.0
# 264                    -2.0

# %%
df['mean_turtles_month_2014'] = (df['mean_turtles_month'] + df['mean_turtles_2014']) / 2
df['mean_turtles_month_2014'] = df['mean_turtles_month_2014'].round()
# Displaying the DataFrame to verify changes
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  diff_2011
# 0                   14                 12                   14         -6  \
# 1                    4                  4                    2         -2
# 2                   10                 11                   16          3
# 3                    0                  0                    0         -1
# 4                    2                  1                    2         -1
# ..                 ...                ...                  ...        ...
# 260                  3                  3                    1         -3
# 261                  2                  2                    2         -2
# 262                  4                  4                    1         -4
# 263                  0                  0                    0          0
# 264                  1                  1                    1         -1
#
#      diff_2014  diff_2015  diff_last2y  mean_turtles_month  diff_month
# 0           -5         -3           -5                10.0        -1.0  \
# 1           -1         -1            1                 4.0        -1.0
# 2            2          1           -4                 8.0         4.0
# 3            0          0            0                 1.0        -1.0
# 4            1          2            1                 3.0         0.0
# ..         ...        ...          ...                 ...         ...
# 260         -3         -3           -1                10.0       -10.0
# 261         -2         -2           -2                 4.0        -4.0
# 262         -4         -4           -1                 8.0        -8.0
# 263          0          0            0                 1.0        -1.0
# 264         -1         -1           -1                 3.0        -3.0
#
#      mean_turtles_month_2014
# 0                       12.0
# 1                        4.0
# 2                        9.0
# 3                        0.0
# 4                        2.0
# ..                       ...
# 260                      6.0
# 261                      3.0
# 262                      6.0
# 263                      0.0
# 264                      2.0
#
# [265 rows x 14 columns]

# %%
df['mean_turtles_month_2014_last2y'] = ((df['mean_turtles_month_2014'] * 9) + df['mean_turtles_last2y']) / 10
df['mean_turtles_month_2014_last2y'] = df['mean_turtles_month_2014_last2y'].round()
# Displaying the DataFrame to verify changes
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  diff_2011
# 0                   14                 12                   14         -6  \
# 1                    4                  4                    2         -2
# 2                   10                 11                   16          3
# 3                    0                  0                    0         -1
# 4                    2                  1                    2         -1
# ..                 ...                ...                  ...        ...
# 260                  3                  3                    1         -3
# 261                  2                  2                    2         -2
# 262                  4                  4                    1         -4
# 263                  0                  0                    0          0
# 264                  1                  1                    1         -1
#
#      diff_2014  diff_2015  diff_last2y  mean_turtles_month  diff_month
# 0           -5         -3           -5                10.0        -1.0  \
# 1           -1         -1            1                 4.0        -1.0
# 2            2          1           -4                 8.0         4.0
# 3            0          0            0                 1.0        -1.0
# 4            1          2            1                 3.0         0.0
# ..         ...        ...          ...                 ...         ...
# 260         -3         -3           -1                10.0       -10.0
# 261         -2         -2           -2                 4.0        -4.0
# 262         -4         -4           -1                 8.0        -8.0
# 263          0          0            0                 1.0        -1.0
# 264         -1         -1           -1                 3.0        -3.0
#
#      mean_turtles_month_2014  diff_month_2014  mean_turtles_month_2014_last2y
# 0                       12.0             -3.0                            12.0  \
# 1                        4.0             -1.0                             4.0
# 2                        9.0              3.0                            10.0
# 3                        0.0              0.0                             0.0
# 4                        2.0              1.0                             2.0
# ..                       ...              ...                             ...
# 260                      6.0             -6.0                             6.0
# 261                      3.0             -3.0                             3.0
# 262                      6.0             -6.0                             6.0
# 263                      0.0              0.0                             0.0
# 264                      2.0             -2.0                             2.0
#
#      diff_month_2014_last2y
# 0                      -3.0
# 1                      -1.0
# 2                       2.0
# 3                       0.0
# 4                       1.0
# ..                      ...
# 260                    -5.0
# 261                    -3.0
# 262                    -5.0
# 263                     0.0
# 264                    -2.0
#
# [265 rows x 17 columns]

# %%
df['diff_month_2014'] = df['actual_number'] - df['mean_turtles_month_2014']
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  diff_2011
# 0                   14                 12                   14         -6  \
# 1                    4                  4                    2         -2
# 2                   10                 11                   16          3
# 3                    0                  0                    0         -1
# 4                    2                  1                    2         -1
# ..                 ...                ...                  ...        ...
# 260                  3                  3                    1         -3
# 261                  2                  2                    2         -2
# 262                  4                  4                    1         -4
# 263                  0                  0                    0          0
# 264                  1                  1                    1         -1
#
#      diff_2014  diff_2015  diff_last2y  mean_turtles_month  diff_month
# 0           -5         -3           -5                10.0        -1.0  \
# 1           -1         -1            1                 4.0        -1.0
# 2            2          1           -4                 8.0         4.0
# 3            0          0            0                 1.0        -1.0
# 4            1          2            1                 3.0         0.0
# ..         ...        ...          ...                 ...         ...
# 260         -3         -3           -1                10.0       -10.0
# 261         -2         -2           -2                 4.0        -4.0
# 262         -4         -4           -1                 8.0        -8.0
# 263          0          0            0                 1.0        -1.0
# 264         -1         -1           -1                 3.0        -3.0
#
#      mean_turtles_month_2014  diff_month_2014  mean_turtles_month_2014_last2y
# 0                       12.0             -3.0                            12.0  \
# 1                        4.0             -1.0                             4.0
# 2                        9.0              3.0                            10.0
# 3                        0.0              0.0                             0.0
# 4                        2.0              1.0                             2.0
# ..                       ...              ...                             ...
# 260                      6.0             -6.0                             6.0
# 261                      3.0             -3.0                             3.0
# 262                      6.0             -6.0                             6.0
# 263                      0.0              0.0                             0.0
# 264                      2.0             -2.0                             2.0
#
#      diff_month_2014_last2y
# 0                      -3.0
# 1                      -1.0
# 2                       2.0
# 3                       0.0
# 4                       1.0
# ..                      ...
# 260                    -5.0
# 261                    -3.0
# 262                    -5.0
# 263                     0.0
# 264                    -2.0
#
# [265 rows x 17 columns]

# %%
df['diff_month_2014_last2y'] = df['actual_number'] - df['mean_turtles_month_2014_last2y']
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  mean_turtles_last2y  diff_2011
# 0                   14                 12                   14         -6  \
# 1                    4                  4                    2         -2
# 2                   10                 11                   16          3
# 3                    0                  0                    0         -1
# 4                    2                  1                    2         -1
# ..                 ...                ...                  ...        ...
# 260                  3                  3                    1         -3
# 261                  2                  2                    2         -2
# 262                  4                  4                    1         -4
# 263                  0                  0                    0          0
# 264                  1                  1                    1         -1
#
#      diff_2014  diff_2015  diff_last2y  mean_turtles_month  diff_month
# 0           -5         -3           -5                10.0        -1.0  \
# 1           -1         -1            1                 4.0        -1.0
# 2            2          1           -4                 8.0         4.0
# 3            0          0            0                 1.0        -1.0
# 4            1          2            1                 3.0         0.0
# ..         ...        ...          ...                 ...         ...
# 260         -3         -3           -1                10.0       -10.0
# 261         -2         -2           -2                 4.0        -4.0
# 262         -4         -4           -1                 8.0        -8.0
# 263          0          0            0                 1.0        -1.0
# 264         -1         -1           -1                 3.0        -3.0
#
#      mean_turtles_month_2014  diff_month_2014  mean_turtles_month_2014_last2y
# 0                       12.0             -3.0                            12.0  \
# 1                        4.0             -1.0                             4.0
# 2                        9.0              3.0                            10.0
# 3                        0.0              0.0                             0.0
# 4                        2.0              1.0                             2.0
# ..                       ...              ...                             ...
# 260                      6.0             -6.0                             6.0
# 261                      3.0             -3.0                             3.0
# 262                      6.0             -6.0                             6.0
# 263                      0.0              0.0                             0.0
# 264                      2.0             -2.0                             2.0
#
#      diff_month_2014_last2y
# 0                      -3.0
# 1                      -1.0
# 2                       2.0
# 3                       0.0
# 4                       1.0
# ..                      ...
# 260                    -6.0
# 261                    -3.0
# 262                    -6.0
# 263                     0.0
# 264                    -2.0
#
# [265 rows x 17 columns]

# %% [markdown]
# # WE ARE WORKING WITH 'DF' FROM NOW ON

# %%
grouped = df.groupby('LandingSite')

# Plotting
for name, group in grouped:
    plt.figure(figsize=(12, 6))
    
    # Plotting mean_turtles as bar graph
    plt.bar(group['week_of_year'], group['actual_number'], color='blue', label='Actual Turtles')
    
    # Plotting number_turtles as line graph
    plt.plot(df.loc[df['LandingSite'] == name, 'week_of_year'], df.loc[df['LandingSite'] == name, 'mean_turtles_2014'], color='red', label='Number of Turtles (Forecast)')
    
    plt.title(f'Comparison of mean_turtles to number_turtles for {name}')
    plt.xlabel('Week of the Year')
    plt.ylabel('Number of Turtles')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
grouped = df.groupby('LandingSite')

# Plotting
for name, group in grouped:
    plt.figure(figsize=(12, 6))
    
    # Plotting mean_turtles as bar graph
    plt.bar(group['week_of_year'], group['actual_number'], color='blue', label='Actual Turtles')
    
    # Plotting number_turtles as line graph
    plt.plot(df.loc[df['LandingSite'] == name, 'week_of_year'], df.loc[df['LandingSite'] == name, 'mean_turtles_month'], color='red', label='Number of Turtles (Forecast)')
    
    plt.title(f'Comparison of monthly mean_turtles to weekly number_turtles for {name}')
    plt.xlabel('Week of the Year')
    plt.ylabel('Number of Turtles')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
grouped = df.groupby('LandingSite')

# Plotting
for name, group in grouped:
    plt.figure(figsize=(12, 6))
    
    # Plotting mean_turtles as bar graph
    plt.bar(group['week_of_year'], group['actual_number'], color='blue', label='Actual Turtles')
    
    # Plotting number_turtles as line graph
    plt.plot(df.loc[df['LandingSite'] == name, 'week_of_year'], df.loc[df['LandingSite'] == name, 'mean_turtles_month_2014'], color='red', label='Number of Turtles (Forecast)')
    
    plt.title(f'Comparison of monthly mean_turtles to weekly number_turtles for {name}')
    plt.xlabel('Week of the Year')
    plt.ylabel('Number of Turtles')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
grouped = df.groupby('LandingSite')

# Plotting
for name, group in grouped:
    plt.figure(figsize=(12, 6))
    
    # Plotting mean_turtles as bar graph
    plt.bar(group['week_of_year'], group['actual_number'], color='blue', label='Actual Turtles')
    
    # Plotting number_turtles as line graph
    plt.plot(df.loc[df['LandingSite'] == name, 'week_of_year'], df.loc[df['LandingSite'] == name, 'mean_turtles_month_2014_last2y'], color='red', label='Number of Turtles (Forecast)')
    
    plt.title(f'Comparison of monthly mean_turtles to weekly number_turtles for {name}')
    plt.xlabel('Week of the Year')
    plt.ylabel('Number of Turtles')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  diff_2011  diff_2014  diff_2015
# 0                   14                 12         -6         -5         -3
# 1                    4                  4         -2         -1         -1
# 2                   10                 11          3          2          1
# 3                    0                  0         -1          0          0
# 4                    2                  1         -1          1          2
# ..                 ...                ...        ...        ...        ...
# 260                  3                  3         -3         -3         -3
# 261                  2                  2         -2         -2         -2
# 262                  4                  4         -4         -4         -4
# 263                  0                  0          0          0          0
# 264                  1                  1         -1         -1         -1
#
# [265 rows x 9 columns]

# %%
df[df['LandingSite'] == 'CaptureSiteCategory_0']
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 5               2  CaptureSiteCategory_0             13                 18
# 10              3  CaptureSiteCategory_0              5                 12
# 15              4  CaptureSiteCategory_0              7                 11
# 20              5  CaptureSiteCategory_0              9                 18
# 25              6  CaptureSiteCategory_0             13                 10
# 30              7  CaptureSiteCategory_0             12                 12
# 35              8  CaptureSiteCategory_0              8                 12
# 40              9  CaptureSiteCategory_0             13                 15
# 45             10  CaptureSiteCategory_0              7                 12
# 50             11  CaptureSiteCategory_0              9                 11
# 55             12  CaptureSiteCategory_0              7                  9
# 60             13  CaptureSiteCategory_0             13                 12
# 65             14  CaptureSiteCategory_0              8                 10
# 70             15  CaptureSiteCategory_0              6                 11
# 75             16  CaptureSiteCategory_0              7                 10
# 80             17  CaptureSiteCategory_0             21                  9
# 85             18  CaptureSiteCategory_0             12                 10
# 90             19  CaptureSiteCategory_0             16                  9
# 95             20  CaptureSiteCategory_0              9                  8
# 100            21  CaptureSiteCategory_0             15                  9
# 105            22  CaptureSiteCategory_0              7                 11
# 110            23  CaptureSiteCategory_0             20                 10
# 115            24  CaptureSiteCategory_0              7                 12
# 120            25  CaptureSiteCategory_0             15                 11
# 125            26  CaptureSiteCategory_0              7                 12
# 130            27  CaptureSiteCategory_0             17                 11
# 135            28  CaptureSiteCategory_0              8                 11
# 140            29  CaptureSiteCategory_0              6                 11
# 145            30  CaptureSiteCategory_0              4                 13
# 150            31  CaptureSiteCategory_0              4                  8
# 155            32  CaptureSiteCategory_0             15                 12
# 160            33  CaptureSiteCategory_0              2                 12
# 165            34  CaptureSiteCategory_0             22                 12
# 170            35  CaptureSiteCategory_0              7                 12
# 175            36  CaptureSiteCategory_0             16                 14
# 180            37  CaptureSiteCategory_0              5                 15
# 185            38  CaptureSiteCategory_0             11                 11
# 190            39  CaptureSiteCategory_0              3                 15
# 195            40  CaptureSiteCategory_0              7                 16
# 200            41  CaptureSiteCategory_0              7                 14
# 205            42  CaptureSiteCategory_0             15                 16
# 210            43  CaptureSiteCategory_0              1                 18
# 215            44  CaptureSiteCategory_0             19                 21
# 220            45  CaptureSiteCategory_0              7                 15
# 225            46  CaptureSiteCategory_0             21                 13
# 230            47  CaptureSiteCategory_0             10                 17
# 235            48  CaptureSiteCategory_0             18                 18
# 240            49  CaptureSiteCategory_0             10                 17
# 245            50  CaptureSiteCategory_0             24                 15
# 250            51  CaptureSiteCategory_0             16                 14
# 255            52  CaptureSiteCategory_0             14                 11
# 260            53  CaptureSiteCategory_0              0                  3
#
#      mean_turtles_2014  mean_turtles_2015  diff_2011  diff_2014  diff_2015
# 0                   14                 12         -6         -5         -3
# 5                   16                  8         -5         -3          5
# 10                  11                 14         -7         -6         -9
# 15                   6                  3         -4          1          4
# 20                  15                 18         -9         -6         -9
# 25                   8                  7          3          5          6
# 30                  12                 14          0          0         -2
# 35                   8                  8         -4          0          0
# 40                  14                 15         -2         -1         -2
# 45                  12                 11         -5         -5         -4
# 50                  11                 10         -2         -2         -1
# 55                   7                  8         -2          0         -1
# 60                  14                 12          1         -1          1
# 65                  11                 11         -2         -3         -3
# 70                  11                  8         -5         -5         -2
# 75                   9                 11         -3         -2         -4
# 80                   8                  6         12         13         15
# 85                  11                 12          2          1          0
# 90                   8                  9          7          8          7
# 95                   9                 11          1          0         -2
# 100                  7                  7          6          8          8
# 105                  9                  9         -4         -2         -2
# 110                 10                  7         10         10         13
# 115                 12                 14         -5         -5         -7
# 120                 10                  8          4          5          7
# 125                 12                 13         -5         -5         -6
# 130                 12                 10          6          5          7
# 135                 10                 10         -3         -2         -2
# 140                 12                 10         -5         -6         -4
# 145                 14                 13         -9        -10         -9
# 150                  6                  6         -4         -2         -2
# 155                 14                 14          3          1          1
# 160                 11                 13        -10         -9        -11
# 165                 14                 14         10          8          8
# 170                 11                 12         -5         -4         -5
# 175                 14                 14          2          2          2
# 180                 14                 14        -10         -9         -9
# 185                 10                  8          0          1          3
# 190                 15                 17        -12        -12        -14
# 195                 14                 14         -9         -7         -7
# 200                 14                 16         -7         -7         -9
# 205                 15                 13         -1          0          2
# 210                 18                 21        -17        -17        -20
# 215                 17                 15         -2          2          4
# 220                 17                 19         -8        -10        -12
# 225                 16                 12          8          5          9
# 230                 17                 17         -7         -7         -7
# 235                 17                 19          0          1         -1
# 240                 15                 14         -7         -5         -4
# 245                 14                 11          9         10         13
# 250                 14                 14          2          2          2
# 255                 12                 10          3          2          4
# 260                  3                  3         -3         -3         -3

# %%
df.describe()
# Out:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count    265.000000     265.000000         265.000000         265.000000  \
# mean      27.000000       5.890566           5.916981           5.988679
# std       15.326003       5.533584           4.390146           4.516370
# min        1.000000       0.000000           0.000000           0.000000
# 25%       14.000000       1.000000           3.000000           3.000000
# 50%       27.000000       5.000000           5.000000           5.000000
# 75%       40.000000       8.000000           8.000000           8.000000
# max       53.000000      29.000000          21.000000          18.000000
#
#        mean_turtles_2015   diff_2011   diff_2014   diff_2015
# count         265.000000  265.000000  265.000000  265.000000
# mean            5.898113   -0.026415   -0.098113   -0.007547
# std             4.637728    4.365331    4.237928    4.806082
# min             0.000000  -17.000000  -17.000000  -20.000000
# 25%             2.000000   -2.000000   -2.000000   -2.000000
# 50%             5.000000    0.000000    0.000000    0.000000
# 75%             8.000000    2.000000    1.000000    2.000000
# max            21.000000   19.000000   16.000000   20.000000

# %%
grouped = df.groupby('LandingSite')

for name, group in grouped:
    print(f"Summary statistics for {name}:")
    print(group.describe())
    print("\n")
# Out:
# Summary statistics for CaptureSiteCategory_0:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count     53.000000      53.000000          53.000000          53.000000  \
# mean      27.000000      10.641509          12.528302          11.981132
# std       15.443445       5.694445           3.220152           3.307861
# min        1.000000       0.000000           3.000000           3.000000
# 25%       14.000000       7.000000          11.000000          10.000000
# 50%       27.000000       9.000000          12.000000          12.000000
# 75%       40.000000      15.000000          15.000000          14.000000
# max       53.000000      24.000000          21.000000          18.000000
#
#        mean_turtles_2015  diff_2011  diff_2014  diff_2015
# count          53.000000  53.000000  53.000000  53.000000
# mean           11.679245  -1.886792  -1.339623  -1.037736
# std             3.886731   6.103783   5.967680   7.057354
# min             3.000000 -17.000000 -17.000000 -20.000000
# 25%             9.000000  -5.000000  -5.000000  -5.000000
# 50%            12.000000  -3.000000  -2.000000  -2.000000
# 75%            14.000000   2.000000   2.000000   4.000000
# max            21.000000  12.000000  13.000000  15.000000
#
#
# Summary statistics for CaptureSiteCategory_1:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count     53.000000      53.000000          53.000000          53.000000  \
# mean      27.000000       5.226415           5.018868           5.132075
# std       15.443445       2.971930           1.681238           1.901798
# min        1.000000       0.000000           2.000000           2.000000
# 25%       14.000000       3.000000           4.000000           4.000000
# 50%       27.000000       5.000000           5.000000           5.000000
# 75%       40.000000       7.000000           6.000000           6.000000
# max       53.000000      12.000000          10.000000          10.000000
#
#        mean_turtles_2015  diff_2011  diff_2014  diff_2015
# count          53.000000  53.000000   53.00000  53.000000
# mean            5.018868   0.207547    0.09434   0.207547
# std             1.926441   3.158374    3.35848   3.398860
# min             2.000000  -7.000000   -9.00000  -8.000000
# 25%             4.000000  -2.000000   -2.00000  -2.000000
# 50%             5.000000   0.000000    0.00000   0.000000
# 75%             6.000000   3.000000    2.00000   2.000000
# max             9.000000   6.000000    7.00000   7.000000
#
#
# Summary statistics for CaptureSiteCategory_2:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count     53.000000      53.000000          53.000000          53.000000  \
# mean      27.000000       8.471698           7.075472           8.207547
# std       15.443445       6.259159           2.110861           2.983019
# min        1.000000       0.000000           4.000000           4.000000
# 25%       14.000000       4.000000           6.000000           6.000000
# 50%       27.000000       7.000000           6.000000           8.000000
# 75%       40.000000      12.000000           9.000000           9.000000
# max       53.000000      29.000000          12.000000          17.000000
#
#        mean_turtles_2015  diff_2011  diff_2014  diff_2015
# count          53.000000  53.000000  53.000000  53.000000
# mean            8.132075   1.396226   0.264151   0.339623
# std             3.519384   5.471393   5.470730   6.354718
# min             3.000000  -7.000000 -12.000000 -16.000000
# 25%             6.000000  -3.000000  -4.000000  -4.000000
# 50%             7.000000   0.000000  -1.000000  -1.000000
# 75%             9.000000   5.000000   3.000000   3.000000
# max            21.000000  19.000000  16.000000  20.000000
#
#
# Summary statistics for CaptureSiteCategory_3:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count     53.000000      53.000000          53.000000          53.000000  \
# mean      27.000000       0.113208           0.603774           0.377358
# std       15.443445       0.319878           0.599347           0.562495
# min        1.000000       0.000000           0.000000           0.000000
# 25%       14.000000       0.000000           0.000000           0.000000
# 50%       27.000000       0.000000           1.000000           0.000000
# 75%       40.000000       0.000000           1.000000           1.000000
# max       53.000000       1.000000           2.000000           2.000000
#
#        mean_turtles_2015  diff_2011  diff_2014  diff_2015
# count          53.000000  53.000000  53.000000  53.000000
# mean            0.320755  -0.490566  -0.264151  -0.207547
# std             0.546794   0.668599   0.593262   0.566992
# min             0.000000  -2.000000  -2.000000  -2.000000
# 25%             0.000000  -1.000000  -1.000000   0.000000
# 50%             0.000000  -1.000000   0.000000   0.000000
# 75%             1.000000   0.000000   0.000000   0.000000
# max             2.000000   1.000000   1.000000   1.000000
#
#
# Summary statistics for CaptureSiteCategory_4:
#        week_of_year  actual_number  mean_turtles_2011  mean_turtles_2014
# count     53.000000      53.000000          53.000000          53.000000  \
# mean      27.000000       5.000000           4.358491           4.245283
# std       15.443445       3.137858           1.360067           1.492361
# min        1.000000       0.000000           1.000000           1.000000
# 25%       14.000000       3.000000           4.000000           3.000000
# 50%       27.000000       5.000000           4.000000           4.000000
# 75%       40.000000       7.000000           5.000000           5.000000
# max       53.000000      12.000000           7.000000           8.000000
#
#        mean_turtles_2015  diff_2011  diff_2014  diff_2015
# count          53.000000  53.000000  53.000000  53.000000
# mean            4.339623   0.641509   0.754717   0.660377
# std             1.890700   3.579291   3.390630   3.668700
# min             1.000000  -6.000000  -6.000000  -6.000000
# 25%             3.000000  -2.000000  -1.000000  -2.000000
# 50%             4.000000   0.000000   1.000000   1.000000
# 75%             6.000000   3.000000   3.000000   3.000000
# max             9.000000   9.000000   9.000000   9.000000

# %%
# Calculate RMSE
rmse_2015 = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_2015']))
# Calculate R-squared
r_squared_2015 = r2_score(df['actual_number'], df['mean_turtles_2015'])

# Calculate RMSE
rmse_2014 = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_2014']))
# Calculate R-squared
r_squared_2014 = r2_score(df['actual_number'], df['mean_turtles_2014'])

# Calculate RMSE
rmse_2011 = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_2011']))
# Calculate R-squared
r_squared_2011 = r2_score(df['actual_number'], df['mean_turtles_2011'])

# Calculate RMSE
rmse_month = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_month']))
# Calculate R-squared
r_squared_month = r2_score(df['actual_number'], df['mean_turtles_month'])

# Calculate RMSE
rmse_month_2014 = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_month_2014']))
# Calculate R-squared
r_squared_month_2014 = r2_score(df['actual_number'], df['mean_turtles_month_2014'])

# Calculate RMSE
rmse_month_2014_last2y = np.sqrt(mean_squared_error(df['actual_number'], df['mean_turtles_month_2014_last2y']))
# Calculate R-squared
r_squared_month_2014_last2y = r2_score(df['actual_number'], df['mean_turtles_month_2014_last2y'])


print(f"RMSE (2015): {rmse_2015}")
print(f"R-squared (2015): {r_squared_2015}")

print(f"RMSE (2014): {rmse_2014}")
print(f"R-squared (2014): {r_squared_2014}")

print(f"RMSE (2011): {rmse_2011}")
print(f"R-squared (2011): {r_squared_2011}")

print(f"RMSE (month (2014+)): {rmse_month}")
print(f"R-squared (month (2014+)): {r_squared_month}")

print(f"RMSE (monthly and weekly averaged (both 2014+)): {rmse_month_2014}")
print(f"R-squared (month and weekly averaged (both 2014+)): {r_squared_month_2014}")

print("Here, I used the above monthly and weekly average (both from 2014 onward), weighted it by 4 parts, and the last 1 part comes from the weekly averages of only the last two years. This skews the data toward more recent years.")
print(f"RMSE (monthly and weekly PLUS last 2 years weighted)): {rmse_month_2014_last2y}")
print(f"R-squared (month and weekly LUS last 2 years weighted): {r_squared_month_2014_last2y}")
# Out:
# RMSE (2015): 4.797011648382457
# R-squared (2015): 0.2456542623659449
# RMSE (2014): 4.23106213526259
# R-squared (2014): 0.413149199846514
# RMSE (2011): 4.357167160022365
# R-squared (2011): 0.37764621088275974
# RMSE (month (2014+)): 4.127222100172335
# R-squared (month (2014+)): 0.44160107253523695
# RMSE (monthly and weekly averaged (both 2014+)): 4.078475482842939
# R-squared (month and weekly averaged (both 2014+)): 0.4547136747309093
# Here, I used the above monthly and weekly average (both from 2014 onward), weighted it by 4 parts, and the last 1 part comes from the weekly averages of only the last two years. This skews the data toward more recent years.
# RMSE (monthly and weekly PLUS last 2 years weighted)): 4.115318828062265
# R-squared (month and weekly LUS last 2 years weighted): 0.4448173711870057

# %%
df_no3 = df[df['LandingSite'] != 'CaptureSiteCategory_3']
df_no3
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 4               1  CaptureSiteCategory_4              3                  4
# 5               2  CaptureSiteCategory_0             13                 18
# ..            ...                    ...            ...                ...
# 259            52  CaptureSiteCategory_4              5                  4
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  diff_2011  diff_2014  diff_2015
# 0                   14                 12         -6         -5         -3
# 1                    4                  4         -2         -1         -1
# 2                   10                 11          3          2          1
# 4                    2                  1         -1          1          2
# 5                   16                  8         -5         -3          5
# ..                 ...                ...        ...        ...        ...
# 259                  4                  4          1          1          1
# 260                  3                  3         -3         -3         -3
# 261                  2                  2         -2         -2         -2
# 262                  4                  4         -4         -4         -4
# 264                  1                  1         -1         -1         -1
#
# [212 rows x 9 columns]

# %%
# Calculate RMSE
rmse_2015_no3 = np.sqrt(mean_squared_error(df_no3['actual_number'], df_no3['mean_turtles_2015']))
# Calculate R-squared
r_squared_2015_no3 = r2_score(df_no3['actual_number'], df_no3['mean_turtles_2015'])

# Calculate RMSE
rmse_2014_no3 = np.sqrt(mean_squared_error(df_no3['actual_number'], df_no3['mean_turtles_2014']))
# Calculate R-squared
r_squared_2014_no3 = r2_score(df_no3['actual_number'], df_no3['mean_turtles_2014'])

# Calculate RMSE
rmse_2011_no3 = np.sqrt(mean_squared_error(df_no3['actual_number'], df_no3['mean_turtles_2011']))
# Calculate R-squared
r_squared_2011_no3 = r2_score(df_no3['actual_number'], df_no3['mean_turtles_2011'])

print("WITHOUT CATEGORY 3!")
print(f"RMSE (2015): {rmse_2015_no3}")
print(f"R-squared (2015): {r_squared_2015_no3}")

print(f"RMSE (2014): {rmse_2014_no3}")
print(f"R-squared (2014): {r_squared_2014_no3}")

print(f"RMSE (2011): {rmse_2011_no3}")
print(f"R-squared (2011): {r_squared_2011_no3}")
# Out:
# WITHOUT CATEGORY 3!
# RMSE (2015): 5.354860250453488
# R-squared (2015): -0.0360951593076666
# RMSE (2014): 4.719489898883181
# R-squared (2014): 0.19518977755374212
# RMSE (2011): 4.854000489773047
# R-squared (2011): 0.148660088708374

# %% [markdown]
# # Baseline Model:
# Training Data 2014-2017; Test Data 2018
#
# Means of Turtle Capture by Week-of-Year per 5 LandingSites
#
# RMSE (2014): 4.23106213526259
#
# R-squared (2014): 0.413149199846514

# %% [markdown]
# So far my (di) best score using month smoothing is:
#
# RMSE (month): 4.127222100172335
#
# R-squared (month): 0.44160107253523695

# %%
df
# Out:
#      week_of_year            LandingSite  actual_number  mean_turtles_2011
# 0               1  CaptureSiteCategory_0              9                 15  \
# 1               1  CaptureSiteCategory_1              3                  5
# 2               1  CaptureSiteCategory_2             12                  9
# 3               1  CaptureSiteCategory_3              0                  1
# 4               1  CaptureSiteCategory_4              3                  4
# ..            ...                    ...            ...                ...
# 260            53  CaptureSiteCategory_0              0                  3
# 261            53  CaptureSiteCategory_1              0                  2
# 262            53  CaptureSiteCategory_2              0                  4
# 263            53  CaptureSiteCategory_3              0                  0
# 264            53  CaptureSiteCategory_4              0                  1
#
#      mean_turtles_2014  mean_turtles_2015  diff_2011  diff_2014  diff_2015
# 0                   14                 12         -6         -5         -3  \
# 1                    4                  4         -2         -1         -1
# 2                   10                 11          3          2          1
# 3                    0                  0         -1          0          0
# 4                    2                  1         -1          1          2
# ..                 ...                ...        ...        ...        ...
# 260                  3                  3         -3         -3         -3
# 261                  2                  2         -2         -2         -2
# 262                  4                  4         -4         -4         -4
# 263                  0                  0          0          0          0
# 264                  1                  1         -1         -1         -1
#
#      mean_turtles_month  diff_month
# 0                  10.0        -1.0
# 1                   4.0        -1.0
# 2                   8.0         4.0
# 3                   1.0        -1.0
# 4                   3.0         0.0
# ..                  ...         ...
# 260                10.0       -10.0
# 261                 4.0        -4.0
# 262                 8.0        -8.0
# 263                 1.0        -1.0
# 264                 3.0        -3.0
#
# [265 rows x 11 columns]

# %%
df_train2
# Out:
#       Date_TimeCaught    CaptureSite ForagingGround       Fisher
# 45         2014-05-28  CaptureSite_0          creek  Fisher_1841  \
# 46         2014-06-15  CaptureSite_0          ocean  Fisher_1625
# 47         2014-07-25  CaptureSite_0          ocean  Fisher_2100
# 48         2014-08-26  CaptureSite_0          ocean  Fisher_1217
# 49         2014-09-14  CaptureSite_0          ocean  Fisher_1964
# ...               ...            ...            ...          ...
# 17784      2017-12-28  CaptureSite_9          ocean  Fisher_1551
# 17785      2017-12-29  CaptureSite_9          ocean  Fisher_1343
# 17786      2017-12-30  CaptureSite_9          ocean  Fisher_1551
# 17787      2017-12-30  CaptureSite_9          ocean  Fisher_1472
# 17788      2017-12-31  CaptureSite_9          ocean  Fisher_1551
#
#                  LandingSite  Weight_Kg    Status  area_sqcm    Type  year
# 45     CaptureSiteCategory_2       5.92  Released  13.246000  Type_1  2014  \
# 46     CaptureSiteCategory_2       9.27  Released  18.914400  Type_1  2014
# 47     CaptureSiteCategory_2       3.95  Released  11.486171  Type_1  2014
# 48     CaptureSiteCategory_2       8.56  Released  16.596600  Type_1  2014
# 49     CaptureSiteCategory_2       2.79  Released   7.823100  Type_1  2014
# ...                      ...        ...       ...        ...     ...   ...
# 17784  CaptureSiteCategory_1       6.81  Released  13.516800  Type_1  2017
# 17785  CaptureSiteCategory_1       5.93  Released  14.280300  Type_1  2017
# 17786  CaptureSiteCategory_1      16.50  Released  24.462500  Type_1  2017
# 17787  CaptureSiteCategory_1      22.70  Released  35.420000  Type_1  2017
# 17788  CaptureSiteCategory_1      11.20  Released  18.998000  Type_1  2017
#
#        month  week_of_year  year_woy
# 45         5            22    201422
# 46         6            24    201424
# 47         7            30    201430
# 48         8            35    201435
# 49         9            37    201437
# ...      ...           ...       ...
# 17784     12            52    201752
# 17785     12            52    201752
# 17786     12            52    201752
# 17787     12            52    201752
# 17788     12            52    201752
#
# [6167 rows x 13 columns]

# %%
# Grouping by 'LandingSite', 'year', and 'week_of_year' without performing aggregation
ordered_df = df_train2.groupby(['LandingSite', 'year', 'week_of_year']).first().reset_index()

# Printing the ordered DataFrame
ordered_df.head(30)
# Out:
#               LandingSite  year  week_of_year Date_TimeCaught     CaptureSite
# 0   CaptureSiteCategory_0  2014             1      2014-12-29  CaptureSite_15  \
# 1   CaptureSiteCategory_0  2014             2      2014-01-07  CaptureSite_15
# 2   CaptureSiteCategory_0  2014             3      2014-01-13  CaptureSite_20
# 3   CaptureSiteCategory_0  2014             4      2014-01-21  CaptureSite_15
# 4   CaptureSiteCategory_0  2014             5      2014-01-27  CaptureSite_15
# 5   CaptureSiteCategory_0  2014             6      2014-02-04  CaptureSite_15
# 6   CaptureSiteCategory_0  2014             7      2014-02-12  CaptureSite_15
# 7   CaptureSiteCategory_0  2014             8      2014-02-19  CaptureSite_15
# 8   CaptureSiteCategory_0  2014             9      2014-02-24  CaptureSite_15
# 9   CaptureSiteCategory_0  2014            10      2014-03-08  CaptureSite_15
# 10  CaptureSiteCategory_0  2014            11      2014-03-10  CaptureSite_15
# 11  CaptureSiteCategory_0  2014            12      2014-03-22  CaptureSite_15
# 12  CaptureSiteCategory_0  2014            13      2014-03-24  CaptureSite_15
# 13  CaptureSiteCategory_0  2014            14      2014-04-04  CaptureSite_15
# 14  CaptureSiteCategory_0  2014            15      2014-04-07  CaptureSite_15
# 15  CaptureSiteCategory_0  2014            16      2014-04-15  CaptureSite_15
# 16  CaptureSiteCategory_0  2014            17      2014-04-22  CaptureSite_15
# 17  CaptureSiteCategory_0  2014            18      2014-05-03  CaptureSite_15
# 18  CaptureSiteCategory_0  2014            19      2014-05-06  CaptureSite_15
# 19  CaptureSiteCategory_0  2014            20      2014-05-12  CaptureSite_15
# 20  CaptureSiteCategory_0  2014            21      2014-05-19  CaptureSite_15
# 21  CaptureSiteCategory_0  2014            22      2014-05-26  CaptureSite_20
# 22  CaptureSiteCategory_0  2014            23      2014-06-04  CaptureSite_11
# 23  CaptureSiteCategory_0  2014            24      2014-06-13  CaptureSite_11
# 24  CaptureSiteCategory_0  2014            25      2014-06-17  CaptureSite_11
# 25  CaptureSiteCategory_0  2014            26      2014-06-23  CaptureSite_15
# 26  CaptureSiteCategory_0  2014            27      2014-07-04  CaptureSite_11
# 27  CaptureSiteCategory_0  2014            28      2014-07-08  CaptureSite_15
# 28  CaptureSiteCategory_0  2014            29      2014-07-20  CaptureSite_15
# 29  CaptureSiteCategory_0  2014            30      2014-07-21  CaptureSite_15
#
#    ForagingGround       Fisher  Weight_Kg    Status  area_sqcm    Type  month
# 0           creek  Fisher_1472       5.40  Released  12.685200  Type_0     12  \
# 1           creek   Fisher_651       1.00  Released  14.271350  Type_0      1
# 2           creek  Fisher_2081      11.50  Released  20.957200  Type_0      1
# 3           creek  Fisher_1486      10.50  Released  16.285500  Type_0      1
# 4           creek  Fisher_1085       8.50  Released  15.276000  Type_0      1
# 5           creek   Fisher_996       4.50  Released   8.568000  Type_0      2
# 6           creek  Fisher_1230       3.50  Released   8.631500  Type_0      2
# 7           creek   Fisher_873       6.50  Released  12.702000  Type_0      2
# 8           creek   Fisher_651       5.50  Released  10.780000  Type_0      2
# 9           creek    Fisher_92       5.50  Released  10.626000  Type_0      3
# 10          creek   Fisher_890       3.50  Released   8.113000  Type_0      3
# 11          creek  Fisher_1415       6.00  Released  14.129000  Type_0      3
# 12          creek   Fisher_506       6.50  Released  11.118000  Type_0      3
# 13          creek  Fisher_1447       6.00  Released   9.006000  Type_0      4
# 14          creek  Fisher_1726       9.00  Released  15.244800  Type_0      4
# 15          creek  Fisher_1230       4.00  Released   9.821000  Type_0      4
# 16          creek  Fisher_1230       5.38  Released  11.881800  Type_0      4
# 17          creek  Fisher_2046       5.56  Released  12.271700  Type_0      5
# 18          creek   Fisher_873       4.36  Released  11.277500  Type_0      5
# 19          creek  Fisher_1085       8.73  Released  17.440000  Type_0      5
# 20          creek    Fisher_92       4.34  Released  10.985000  Type_0      5
# 21          creek   Fisher_174      42.92  Released  46.023800  Type_0      5
# 22          creek  Fisher_1577       5.60  Released  12.629000  Type_0      6
# 23          creek  Fisher_1233       7.28  Released  16.160300  Type_0      6
# 24          creek  Fisher_1156      10.87  Released  19.788100  Type_0      6
# 25          creek  Fisher_1085       4.79  Released  12.227500  Type_0      6
# 26          creek   Fisher_155      11.49  Released  18.956700  Type_0      7
# 27          creek   Fisher_863       9.27  Released  17.700691  Type_0      7
# 28          creek    Fisher_92       8.85  Released  17.776000  Type_0      7
# 29          creek  Fisher_2046       6.00  Released  13.552981  Type_0      7
#
#     year_woy
# 0     201401
# 1     201402
# 2     201403
# 3     201404
# 4     201405
# 5     201406
# 6     201407
# 7     201408
# 8     201409
# 9     201410
# 10    201411
# 11    201412
# 12    201413
# 13    201414
# 14    201415
# 15    201416
# 16    201417
# 17    201418
# 18    201419
# 19    201420
# 20    201421
# 21    201422
# 22    201423
# 23    201424
# 24    201425
# 25    201426
# 26    201427
# 27    201428
# 28    201429
# 29    201430

# %%
all_weeks = pd.DataFrame({'week_of_year': range(1, 54)})
all_sites = pd.DataFrame({'LandingSite': turtle_week_train['LandingSite'].unique()})
all_years = pd.DataFrame({'year': '2014', '2015', '2016', '2017'})

# Cartesian product to get all possible combinations of 'week_of_year' and 'LandingSite'
all_combinations = all_weeks.assign(key=1).merge(all_sites.assign(key=1), on='key').drop(columns='key')

# Merge with the aggregated DataFrame to fill in missing values with 0
ordered_df_filled = all_combinations.merge(ordered_df, how='left', on=['LandingSite', 'week_of_year']).fillna(0)

ordered_df_filled
# Out:
#      week_of_year            LandingSite
# 0               1  CaptureSiteCategory_0
# 1               1  CaptureSiteCategory_1
# 2               1  CaptureSiteCategory_2
# 3               1  CaptureSiteCategory_3
# 4               1  CaptureSiteCategory_4
# ..            ...                    ...
# 260            53  CaptureSiteCategory_0
# 261            53  CaptureSiteCategory_1
# 262            53  CaptureSiteCategory_2
# 263            53  CaptureSiteCategory_3
# 264            53  CaptureSiteCategory_4
#
# [265 rows x 2 columns]

# %% [markdown]
# ## Rakib Helped

# %% [markdown]
# whatever model we have, we will use 2014-2017 to train, test on 2018 -- then we will put 2018 into the train, and forecast for 2019
#
# new model ideas to beat the baseline:
#
# potentially different models for each landing site
#
# potentially using time series
#
# potentially changing week of year to one hot encoder categories
#
# potentially creating ongoing linear time of weeks (so weeks 1 - 200+)
#
# lag 1, lag 2, etc -- new features which grab values from the previous row, column to left for example
#
# there is a photo of the board

# %% [markdown]
# ## tomorrow plan

# %% [markdown]
# ### morning modelling
# work on trying to beat baseline until 11:30, meet up and discuss 11:3--12:30
# lunch: 12:30 - 1:30
# deliverable stuff: divvying up python script, jupyter notebook and slides
#
# wednesday morning: fine tuning presentation
